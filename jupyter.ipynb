# %%
import os
import sys
import numpy as np
import pandas as pd
import sklearn as sk
from sklearn.model_selection import train_test_split

# %%
captions_path=os.path.join("data", "captions.txt")
image_captions = {}
with open(captions_path, "r") as f:
    for line in f:
        image_name, caption = line.strip().split(".jpg,")
        image_path = os.path.join("data", "Images", f"{image_name}.jpg")
        if image_path in image_captions:
            image_captions[image_path].append(caption)
        else:
            image_captions[image_path] = [caption]

# %%
image_captions
# Out:
# {'data\\Images\\1000268201_693b08cb0e.jpg': ['A child in a pink dress is climbing up a set of stairs in an entry way .',
#   'A girl going into a wooden building .',
#   'A little girl climbing into a wooden playhouse .',
#   'A little girl climbing the stairs to her playhouse .',
#   'A little girl in a pink dress going into a wooden cabin .'],
#  'data\\Images\\1001773457_577c3a7d70.jpg': ['A black dog and a spotted dog are fighting',
#   'A black dog and a tri-colored dog playing with each other on the road .',
#   'A black dog and a white dog with brown spots are staring at each other in the street .',
#   'Two dogs of different breeds looking at each other on the road .',
#   'Two dogs on pavement moving toward each other .'],
#  'data\\Images\\1002674143_1b742ab4b8.jpg': ['A little girl covered in paint sits in front of a painted rainbow with her hands in a bowl .',
#   'A little girl is sitting in front of a large painted rainbow .',
#   'A small girl in the grass plays with fingerpaints in front of a white canvas with a rainbow on it .',
#   'There is a girl with pigtails sitting in front of a rainbow painting .',
#   'Young girl with pigtails painting outside in the grass .'],
#  'data\\Images\\1003163366_44323f5815.jpg': ['A man lays on a bench while his dog sits by him .',
#   'A man lays on the bench to which a white dog is also tied .',
#   'a man sleeping on a bench outside with a white and black dog sitting next to him .',
#   'A shirtless man lies on a park bench with his dog .',
#   'man laying on bench holding leash of dog sitting on ground'],
#  'data\\Images\\1007129816_e794419615.jpg': ['A man in an orange hat starring at something .',
#   'A man wears an orange hat and glasses .',
#   'A man with gauges and glasses is wearing a Blitz hat .',
#   'A man with glasses is wearing a beer can crocheted hat .',
#   'The man with pierced ears is wearing glasses and an orange hat .'],
#  'data\\Images\\1007320043_627395c3d8.jpg': ['A child playing on a rope net .',
#   'A little girl climbing on red roping .',
#   'A little girl in pink climbs a rope bridge at the park .',
#   'A small child grips onto the red ropes at the playground .',
#   'The small child climbs on a red ropes on a playground .'],
#  'data\\Images\\1009434119_febe49276a.jpg': ['A black and white dog is running in a grassy garden surrounded by a white fence .',
#   'A black and white dog is running through the grass .',
#   'A Boston terrier is running in the grass .',
#   'A Boston Terrier is running on lush green grass in front of a white fence .',
#   'A dog runs on the green grass near a wooden fence .'],
#  'data\\Images\\1012212859_01547e3f17.jpg': ['"A dog shakes its head near the shore , a red ball next to it ."',
#   'A white dog shakes on the edge of a beach with an orange ball .',
#   '"Dog with orange ball at feet , stands on shore shaking off water"',
#   'White dog playing with a red ball on the shore near the water .',
#   'White dog with brown ears standing near water with head turned to one side .'],
#  'data\\Images\\1015118661_980735411b.jpg': ['A boy smiles in front of a stony wall in a city .',
#   'A little boy is standing on the street while a man in overalls is working on a stone wall .',
#   'A young boy runs aross the street .',
#   'A young child is walking on a stone paved street with a metal pole and a man behind him .',
#   'Smiling boy in white shirt and blue jeans in front of rock wall with man in overalls behind him .'],
#  'data\\Images\\1015584366_dfcec3c85a.jpg': ['A black dog leaps over a log .',
#   'A grey dog is leaping over a fallen tree .',
#   'A large black dog leaps a fallen log .',
#   'A mottled black and grey dog in a blue collar jumping over a fallen tree .',
#   'The black dog jumped the tree stump .'],
#  'data\\Images\\101654506_8eb26cfb60.jpg': ['A brown and white dog is running through the snow .',
#   'A dog is running in the snow',
#   'A dog running through snow .',
#   'a white and brown dog is running through a snow covered field .',
#   'The white and brown dog is running over the surface of the snow .'],
#  'data\\Images\\101669240_b2d3e7f17b.jpg': ['A man in a hat is displaying pictures next to a skier in a blue hat .',
#   'A man skis past another man displaying paintings in the snow .',
#   'A person wearing skis looking at framed pictures set up in the snow .',
#   'A skier looks at framed pictures in the snow next to trees .',
#   'Man on skis looking at artwork for sale in the snow'],
#  'data\\Images\\1016887272_03199f49c4.jpg': ['A collage of one person climbing a cliff .',
#   'A group of people are rock climbing on a rock climbing wall .',
#   'A group of people climbing a rock while one man belays',
#   'Seven climbers are ascending a rock face whilst another man stands holding the rope .',
#   'Several climbers in a row are climbing the rock while the man in red watches and holds the line .'],
#  'data\\Images\\1019077836_6fc9b15408.jpg': ['A brown dog chases the water from a sprinkler on a lawn .',
#   'a brown dog plays with the hose .',
#   'A brown dog running on a lawn near a garden hose',
#   'A dog is playing with a hose .',
#   'Large brown dog running away from the sprinkler in the grass .'],
#  'data\\Images\\1019604187_d087bf9a5f.jpg': ['A dog prepares to catch a thrown object in a field with nearby cars .',
#   'A white dog is about to catch a yellow ball in its mouth .',
#   'A white dog is about to catch a yellow dog toy .',
#   'A white dog is ready to catch a yellow ball flying through the air .',
#   'A white dog running after a yellow ball'],
#  'data\\Images\\1020651753_06077ec457.jpg': ['a black and white dog jumping in the air to get a toy .',
#   'A black and white dog jumps up towards a yellow toy .',
#   'A dog leaps to catch a ball in a field .',
#   'A white dog is trying to catch a ball in midair over a grassy field .',
#   'The white dog is playing in a green field with a yellow toy .'],
#  'data\\Images\\1022454332_6af2c1449a.jpg': ['A child and a woman are at waters edge in a big city .',
#   'a large lake with a lone duck swimming in it with several people around the edge of it .',
#   'A little boy at a lake watching a duck .',
#   'A young boy waves his hand at the duck in the water surrounded by a green park .',
#   '"Two people are at the edge of a lake , facing the water and the city skyline ."'],
#  'data\\Images\\1022454428_b6b660a67b.jpg': ['"A couple and an infant , being held by the male , sitting next to a pond with a near by stroller ."',
#   'A couple sit on the grass with a baby and stroller .',
#   'A couple with their newborn baby sitting under a tree facing a lake .',
#   'A man and woman care for an infant along the side of a body of water .',
#   'Couple with a baby sit outdoors next to their stroller .'],
#  'data\\Images\\1022975728_75515238d8.jpg': ['A black dog running in the surf .',
#   'A black lab with tags frolicks in the water .',
#   'A dog splashes in the water',
#   'The black dog runs through the water .',
#   'This is a black dog splashing in the water .'],
#  'data\\Images\\102351840_323e3de834.jpg': ['A man drilling a hole in the ice .',
#   'A man is drilling through the frozen ice of a pond .',
#   'A person in the snow drilling a hole in the ice .',
#   'A person standing on a frozen lake .',
#   'Two men are ice fishing .'],
#  'data\\Images\\1024138940_f1fefbdce1.jpg': ['Two different breeds of brown and white dogs play on the beach .',
#   'Two dogs are making a turn on a soft sand beach .',
#   'Two dogs playing in the sand at the beach .',
#   'Two dogs playing together on a beach .',
#   'Two large tan dogs play along a sandy beach .'],
#  'data\\Images\\102455176_5f8ead62d5.jpg': ['A man uses ice picks and crampons to scale ice .',
#   'an ice climber in a blue jacket and black pants is scaling a frozen ice wall .',
#   'An ice climber scaling a frozen waterfall .',
#   'A person in blue and red ice climbing with two picks .',
#   'Climber climbing an ice wall'],
#  'data\\Images\\1026685415_0431cbf574.jpg': ['A black dog carries a green toy in his mouth as he walks through the grass .',
#   'A black dog carrying something through the grass .',
#   'A black dog has a blue toy in its mouth .',
#   'A dog in grass with a blue item in his mouth .',
#   'A wet black dog is carrying a green toy through the grass .'],
#  'data\\Images\\1028205764_7e8df9a2ea.jpg': ['A man and a baby are in a yellow kayak on water .',
#   'A man and a little boy in blue life jackets are rowing a yellow canoe .',
#   'A man and child kayak through gentle waters .',
#   'A man and young boy ride in a yellow kayak .',
#   'Man and child in yellow kayak'],
#  'data\\Images\\1030985833_b0902ea560.jpg': ['A black dog and a brown dog are jumping up to catch a red toy .',
#   'A black dog and a brown dog play with a red toy on a courtyard .',
#   'A brown and black lab are outside and the black lab is catching a toy in its mouth .',
#   'Black dog snaps at red and black object as brown dog lunges .',
#   'The Chocolate Lab jumps too late to get the toy as the Black Lab captures it in the driveway .'],
#  'data\\Images\\103106960_e8a41d64f8.jpg': ['A boy with a stick kneeling in front of a goalie net',
#   'A child in a red jacket playing street hockey guarding a goal .',
#   'A young kid playing the goalie in a hockey rink .',
#   'A young male kneeling in front of a hockey goal with a hockey stick in his right hand .',
#   '"Hockey goalie boy in red jacket crouches by goal , with stick ."'],
#  'data\\Images\\103195344_5d2dc613a3.jpg': ['A man in black is sitting next to a modern art structure in front of a glass building .',
#   'A man sits and reads a newspaper by a sculpture outside of an office building .',
#   'a man sits near a large statue .',
#   'A man sitting in front of a metal sculpture in front of a building .',
#   'The man with the backpack is sitting in a buildings courtyard in front of an art sculpture reading .'],
#  'data\\Images\\103205630_682ca7285b.jpg': ['A tent is being set up on the ice .',
#   'Two men are about to enter an ice fishing tent on a snow covered lake .',
#   'two men setting up a blue ice fishing hut on an iced over lake',
#   '"Two men , standing on an ice , looking into something covered with a blue tarp ."',
#   'Two people standing outside a blue tent structure on a snowy surface .'],
#  'data\\Images\\1032122270_ea6f0beedb.jpg': ['A woman crouches near three dogs in a field .',
#   'Three dogs are playing on grassy hill with a blue sky .',
#   'Three dogs are standing in the grass and a person is sitting next to them',
#   'Three dogs on a grassy hill',
#   'Three dogs stand in a grassy field while a person kneels nearby .'],
#  'data\\Images\\1032460886_4a598ed535.jpg': ['a man is standing in front of a skyscraper',
#   'A man stands in front of a skyscraper .',
#   'A man stands in front of a very tall building .',
#   'Behind the man in a red shirt stands a large skyscraper .',
#   'There is a skyscraper in the distance with a man walking in front of the camera .'],
#  'data\\Images\\1034276567_49bb87c51c.jpg': ['A boy bites hard into a treat while he sits outside .',
#   'A child biting into a baked good .',
#   'A small boy putting something in his mouth with both hands .',
#   'The boy eats his food outside at the table .',
#   'The boy is eating pizza over a tin dish .'],
#  'data\\Images\\104136873_5b5d41be75.jpg': ['People sit on the mountainside and check out the view .',
#   'Three people are on a hilltop overlooking a green valley .',
#   'Three people hang out on top of a big hill .',
#   'Three people overlook a green valley .',
#   'Three people rest on a ledge above the moutains .'],
#  'data\\Images\\1042020065_fb3d3ba5ba.jpg': ['A boy in a green shirt is looking down at many inflatable boats .',
#   'A boy in a green shirt watches kayakers .',
#   'A boy looks over a railing at the many boats and rafts below in the water .',
#   'A young boy overlooking a crowd of inflatable boats .',
#   'A young boy wearing a jersey looks down over a ledge at many boats in the water .'],
#  'data\\Images\\1042590306_95dea0916c.jpg': ['A man and woman pose for the camera while another man looks on .',
#   'A man is holding the hand of a woman up to his mouth in front of some buildings while another man looks on .',
#   'A multiracial couple posing for a picture',
#   '"Asian man and blond woman holding hands outdoors , man in background watches ."',
#   'Guy in blue shirt biting hand of girl in black striped jacket while another guy watches'],
#  'data\\Images\\1045521051_108ebc19be.jpg': ['A person eats takeout while watching a small television .',
#   'A person sits on the floor and eats in front of a television .',
#   'A television with a picture of a girl on it .',
#   'A young man sits on the floor by the television with a fast food meal in front of him .',
#   'Someone is laying in front of the TV eating food .'],
#  'data\\Images\\1048710776_bb5b0a5c7c.jpg': ['a couple of several people sitting on a ledge overlooking the beach',
#   'A group of people sit on a wall at the beach .',
#   'A group of teens sit on a wall by a beach .',
#   'Crowd of people at the beach .',
#   'Several young people sitting on a rail above a crowded beach .'],
#  'data\\Images\\1052358063_eae6744153.jpg': ['A boy takes a jump on his skateboard while another boy with a skateboard watches .',
#   'A child is performing a skateboard trick while another child with a skateboard leans on a wall .',
#   'A little boy skateboarder is doing a trick on his board while another young skateboarder watches .',
#   'a young boy skateboarder jumping on a platform on a skateboard .',
#   'Two skateboarders .'],
#  'data\\Images\\105342180_4d4a40b47f.jpg': ['"A girl paddling down a large river , as seen from behind her ."',
#   'A woman kayaking down a river .',
#   'A woman paddles a boat down a river .',
#   'A woman with a paddle .',
#   'A woman with a paddle sits in a boat on the water .'],
#  'data\\Images\\1053804096_ad278b25f1.jpg': ['A girl in pigtails splashes in the shallow water .',
#   'A girls plays in the surf .',
#   'a girl with pigtails is playing in the ocean by the beach .',
#   'A girl with pigtails plays in the water .',
#   'A young girl in pigtails plays in the water .'],
#  'data\\Images\\1055623002_8195a43714.jpg': ['A group of four children wearing pajamas have a pillow fight .',
#   'A group of kids have a pillow-fight .',
#   'A group of young children playing pillow fight on a bed .',
#   'Children having a pillow fight .',
#   'Four children are having a pillow fight .'],
#  'data\\Images\\1055753357_4fa3d8d693.jpg': ['Two constructions workers sit on a beam taking a break .',
#   'Two construction workers are sitting up on the side of a building .',
#   'Two construction workers sitting on an I-beam .',
#   'Two construction workers take a seat on a steel beam .',
#   'Two men take a break from construction .'],
#  'data\\Images\\1056249424_ef2a2e041c.jpg': ['The children are playing in the water .',
#   '"Two boys , one with a yellow and orange ball , play in some water in front of a field ."',
#   'Two boys play in a puddle .',
#   'Two children play with a balloon in mud on a sunny day .',
#   'Two kids are running and playing in some water .'],
#  'data\\Images\\1056338697_4f7d7ce270.jpg': ['A blond woman in a blue shirt appears to wait for a ride .',
#   'A blond woman is on the street hailing a taxi .',
#   '"A woman is signaling is to traffic , as seen from behind ."',
#   'A woman with blonde hair wearing a blue tube top is waving on the side of the street .',
#   'The woman in the blue dress is holding out her arm at oncoming traffic .'],
#  'data\\Images\\1056359656_662cee0814.jpg': ['A little girl looking at a brochure on train rides',
#   'a young blond girl with a magizine in her hands',
#   'A young girl on a train reads a book about train rides .',
#   'A young girl sits on a seat and looks at a train pamphlet .',
#   'Child sitting down looking at train ride brochure'],
#  'data\\Images\\1056873310_49c665eb22.jpg': ['A brown dog is running after a black dog on a rocky shore .',
#   'A brown dog is running after the black dog .',
#   'Two dogs playing on a beach .',
#   'Two dogs run across stones near a body of water .',
#   'Two dogs run towards each other on a rocky area with water in the background .'],
#  'data\\Images\\1057089366_ca83da0877.jpg': ['A boy descends off the end of a high diving board .',
#   'A child jumps off a high diving board into the pool .',
#   'A kid jumps off the diving board and into the swimming pool below .',
#   'A little kid is jumping off a high dive at the pool .',
#   'The boy is jumping off a high diving board into the pool .'],
#  'data\\Images\\1057210460_09c6f4c6c1.jpg': ['A guy stands by a window taking his overshirt off .',
#   'A man in a tank top stands next to a chrome door .',
#   'A man puts his shirt on near an elevator .',
#   'A man stands by an elevator with his head down .',
#   'The man is putting on his shirt near an elevator .'],
#  'data\\Images\\1057251835_6ded4ada9c.jpg': ['A light-colored dog runs on the beach .',
#   'A small yellow dog runs on a beach',
#   'A tan dog runs on a sandy beach .',
#   'A white dog is running down a rocky beach .',
#   'Light brown dog running along the beach .'],
#  'data\\Images\\106490881_5a2dd9b7bd.jpg': ['A boy in his blue swim shorts at the beach .',
#   'A boy smiles for the camera at a beach .',
#   'A young boy in swimming trunks is walking with his arms outstretched on the beach .',
#   'Children playing on the beach .',
#   'The boy is playing on the shore of an ocean .'],
#  'data\\Images\\106514190_bae200f463.jpg': ['A hiker standing high on a bluff overlooking the mountains below .',
#   "a person on ski 's looks from hill over snow covered landscape",
#   'A skier is overlooking a snow-covered mountain .',
#   'A skier is overlooking the beautiful white snow covered landscape .',
#   'A skier pauses on a mountaintop .'],
#  'data\\Images\\1067180831_a59dc64344.jpg': ['A black and white dog is attempting to catch a yellow and purple object in a low cut yard .',
#   'A black and white dog jumps after a yellow toy .',
#   'a black and white dog jumps to get the Frisbee .',
#   'A black dog is jumping up to catch a purple and green toy .',
#   'A dog jumps to catch a toy .'],
#  'data\\Images\\1067675215_7336a694d6.jpg': ['A man in blue shorts is laying in the street .',
#   'A man in blue shorts lays down outside in a parking lot .',
#   'A man laying down in middle of street during heavy traffic .',
#   'A man lies on a mat in a parking lot between a brown SUV and a yellow pickup with an open door .',
#   'A shirtless man is laying down in the middle of a busy street .'],
#  'data\\Images\\1067790824_f3cc97239b.jpg': ['A white and black dog and a brown dog in sandy terrain .',
#   'A woolly dog chases a Doberman on a beach .',
#   'One dog is chasing another one on the beach .',
#   'The two large dogs are running through sand .',
#   'Two large dogs chasing each other at the beach .'],
#  'data\\Images\\1072153132_53d2bb1b60.jpg': ['A black and white dog catches a toy in midair .',
#   'A dog and a tennis ball .',
#   '"A dog is jumping to catch a object thrown at it ,"',
#   'A dog leaps while chasing a tennis ball through a grassy field .',
#   'A multicolor dog jumping to catch a tennis ball in a grassy field .'],
#  'data\\Images\\107318069_e9f2ef32de.jpg': ['A crowd watching air balloons at night .',
#   'A group of hot air balloons lit up at night .',
#   'People are watching hot air balloons in the park .',
#   'People watching hot air balloons .',
#   'Seven large balloons are lined up at nighttime near a crowd .'],
#  'data\\Images\\1075716537_62105738b4.jpg': ['A child with a helmet on his head rides a bike .',
#   'A little boy rides a bike down a hill on a miniature dirt bike .',
#   'A young boy in a helmet rides a bike on the road .',
#   'The little boy rides his bicycle in a race .',
#   'The young boy pedals quickly at a BMX race .'],
#  'data\\Images\\107582366_d86f2d3347.jpg': ['A group of eight people are gathered around a table at night .',
#   'A group of people gathered around in the dark .',
#   'A group of people sit around a table outside on a porch at night .',
#   'A group of people sit outdoors together at night .',
#   'A group of people sitting at a table in a darkened room .'],
#  'data\\Images\\1075867198_27ca2e7efe.jpg': ['A man in a brown shirt and dark shorts plays on the beach with his two black dogs .',
#   'A man in shorts with two black dogs holds a ball throwing toy at the beach .',
#   'a man playing with two black dogs on the beach',
#   'A man with two dogs on a beach',
#   'Man at the beach with two dogs .'],
#  'data\\Images\\1075881101_d55c46bece.jpg': ['a boy cleans the bubbles off his face .',
#   'A boy covered in suds has his face wiped clean .',
#   'A boy is covered in bubbles .',
#   'A child covered in foam is climbing on a black inflatable ramp .',
#   'A person covered in soapy water is getting cleaned off .'],
#  'data\\Images\\1077546505_a4f6c4daa9.jpg': ['A boy in blue shorts slides down a slide into a pool .',
#   'A boy in blue swimming trunks slides down a yellow slide into a wading pool with inflatable toys floating in the water .',
#   'A boy rides down a slide into a small backyard pool .',
#   'A boy sliding down a slide into a pool with colorful tubes .',
#   'A child is falling off a slide onto colored balloons floating on a pool of water .'],
#  'data\\Images\\1077931201_1e0bb83105.jpg': ['A man in a wetsuit is throwing a baby wearing a wetsuit up into the air .',
#   'A man in a wetsuit is throwing a toddler up in the air and is ready to catch him .',
#   'A man in water throwing a little boy up in the air and waiting for him to come down so he can catch him .',
#   'The man is in the pool and throwing a small boy into the air .',
#   '"While water droplets fly , a man throws a little boy up in the air ."'],
#  'data\\Images\\1079274291_9aaf896cc1.jpg': ['A little boy sticks his tongue out for the camera . Another boy looks on .',
#   'Two boys make faces .',
#   '"Two young boys are looking at the camera , one smiling , the other sticking his tongue out ."',
#   'Two young boys look up at the camera as one sticks out his tongue .',
#   'two young boys making silly faces .'],
#  'data\\Images\\10815824_2997e03d76.jpg': ['A blonde horse and a blonde girl in a black sweatshirt are staring at a fire in a barrel .',
#   'A girl and her horse stand by a fire .',
#   "A girl holding a horse 's lead behind a fire .",
#   '"A man , and girl and two horses are near a contained fire ."',
#   'Two people and two horses watching a fire .'],
#  'data\\Images\\1082252566_8c79beef93.jpg': ['"A bulldog , a sheep dog , and a boxer standing in a yard ."',
#   'A large brown dog is pushing a small Boston terrier with his face while anouther dog watches .',
#   'A large skinny dog stands near two smaller dogs int the dirt .',
#   'There are three dogs starring at a ball in the middle of them .',
#   'Three dogs of various sizes .'],
#  'data\\Images\\1082379191_ec1e53f996.jpg': ['A lady and a man with no shirt sit on a dock .',
#   'A man and a woman are sitting on a dock together .',
#   'A man and a woman sitting on a dock .',
#   'A man and woman sitting on a deck next to a lake .',
#   'A shirtless man and a woman sitting on a dock .'],
#  'data\\Images\\1084040636_97d9633581.jpg': ['A closeup of a white dog that is laying its head on its paws .',
#   'a large white dog lying on the floor .',
#   'A white dog has its head on the ground .',
#   'A white dog is resting its head on a tiled floor with its eyes open .',
#   'A white dog rests its head on the patio bricks .'],
#  'data\\Images\\1084104085_3b06223afe.jpg': ['a woman in a yellow shirt and green shorts is climbing an artificial red wall whilst wearing a safety harness .',
#   'A woman in blue shorts and a white shirt is indoor rock climbing .',
#   'The girl is climbing a rock wall .',
#   '"The girl is in a harness , climbing rocks ."',
#   'Woman climbing an artificial rock wall .'],
#  'data\\Images\\1087168168_70280d024a.jpg': ['A boy is jumping on an inflatable ring and a girl is watching him',
#   'A boy jumping on a water jumphouse',
#   'A teenage boy is jumping on an inflatable slide .',
#   'A young boy jumping and a young girl seating in an inflatable pool .',
#   'Two young kids are playing in the water on an inflated toy .'],
#  'data\\Images\\1087539207_9f77ab3aaf.jpg': ['A family playing on a tractor on a beautiful day',
#   'Children ride a tractor in a field .',
#   'Several children playing on a Polaris vehicle outdoors .',
#   'The children played on the four wheeler in the field .',
#   'The four kids are riding on an ATV in a field .'],
#  'data\\Images\\1088767354_2acee738cf.jpg': ['A woman in a red costume to the left of a man and woman standing together .',
#   'A woman wearing a red costume looks at two other people standing on a street .',
#   'A young woman in a red sequined costume and feather stands on the sidewalk .',
#   'The girl in the salmon colored bikini is standing next to two young people ; one is wearing a black outfit and the other is drinking pop .',
#   'Two young people are approached by a flamboyant young woman dressed in a red bikini and a red feathered headress .'],
#  'data\\Images\\108898978_7713be88fc.jpg': ['Skiiers walking up the hill through a forest .',
#   'Two men are skiing in the snow in a wooded area .',
#   'Two people wearing yellow jackets cross-country skiing .',
#   'Two skiers are making their way through woodland .',
#   'Two skiers are sliding down a trail in the woods .'],
#  'data\\Images\\108899015_bf36131a57.jpg': ['A lone skier is making their way up a mountain .',
#   'Skiiers at the top of a snow covered hill .',
#   'Two hikers climbing a snowy hill .',
#   'Two people are on a snow-covered mountain .',
#   'Two people climbing up a snowy mountain .'],
#  'data\\Images\\1089181217_ee1167f7af.jpg': ['a brown dog running down a paved pathway',
#   'A brown dog running next to grass .',
#   'A dog is running down a road .',
#   'A light brown dog runs down a path happily .',
#   'Energetic brown dog running'],
#  'data\\Images\\1089755335_0bfbfd30e6.jpg': ['A mother and children is fishing on a boardwalk at night .',
#   'A woman and three children stand on a deck with a fishing pole .',
#   'A woman stands with children on a boardwalk at night overlooking the sea .',
#   'Some people on a pier at night with one girl fishing off it .',
#   'Woman with three children fishing over boardwalk in the evening .'],
#  'data\\Images\\109202756_b97fcdc62c.jpg': ['A woman dressed in a blue jacket and blue jeans rides a brown horse near a frozen lake and snow-covered mountain .',
#   'A woman in a blue jacket rides a brown pony near water .',
#   'A woman rides a horse near a frozen lake in the wintertime .',
#   'A young blond woman sitting atop a brown draft horse in the snowy mountains .',
#   'Woman n blue jacket sits on daft horse near a frozen lake .'],
#  'data\\Images\\109202801_c6381eef15.jpg': ['Two draft horses pull a cart through the snow .',
#   'Two golden brown horses pull a sleigh driven by a woman in a blue coat .',
#   'Two horses are pulling a woman in a cart .',
#   'Two horses pull a carriage driven by a woman over snow covered ground .',
#   'Two horses pulling a sled steered by a smiling blond woman .'],
#  'data\\Images\\109260216_85b0be5378.jpg': ['A person climbing down a sheer rock cliff using a rope',
#   '"A person climbs a tall , flat mountain while holding onto a safety rope ."',
#   'A person is climbing a rock while holding onto a white rope .',
#   'A person rappels down a steep incline .',
#   'A person wearing a red vest climbs up a steep rock .'],
#  'data\\Images\\109260218_fca831f933.jpg': ['People stand inside a rock dome .',
#   'Shaft of light in a cave shows three spelunkers',
#   'Spelunkers pose inside a rock cavern while bathed in sunlight from the surface .',
#   'three people sit in a cave .',
#   'Three rock climbers are posing on big rocks .'],
#  'data\\Images\\1093716555_801aacef79.jpg': ['a group of backpackers lay on the dry ground .',
#   'A group of hikers are resting on the ground in front of some mountains .',
#   'People camp with the mountains in the background .',
#   'Several hikers rest with their gear in front of a mountain .',
#   'The group of hikers is resting in front of a mountain .'],
#  'data\\Images\\1093737381_b313cd49ff.jpg': ['A woman in a blue dress stands with a chalk portrait of two children playing by a stream .',
#   'A woman standing in front of a chalk drawing',
#   'A woman stands next to a chalk drawing in front of a barn-like structure .',
#   'A woman stands outside near an elaborate chalk illustration .',
#   'A woman wearing a blue dress is drawing a picture of a boy and a girl on the sidewalk with sidewalk chalk .'],
#  'data\\Images\\1094462889_f9966dafa6.jpg': ['A brown dog plays in a deep pile of snow .',
#   'A dog looking at the camera in snow .',
#   'a dog runs through the snow .',
#   'A tan dog stand in the snow and looks up .',
#   'The brown dog is out in the snow .'],
#  'data\\Images\\1095476286_87d4f8664e.jpg': ['A boy jumping in a fountain .',
#   'a boy plays in the fountains .',
#   'A child plays in a fountain .',
#   'A little boy playing in the water .',
#   'A young boy is jumping through water being sprayed up from the ground .'],
#  'data\\Images\\1095580424_76f0aa8a3e.jpg': ['A Corgi runs out of a tunnel .',
#   'A dog runs out of a tunnel on a course .',
#   'Dog running out of tunnel on obstacle course',
#   'The dog is running out of the tunnel on a dog obedience course .',
#   'The small brown and white dog is running out of a small tunnel .'],
#  'data\\Images\\1095590286_c654f7e5a9.jpg': ['A blond dog and a black and white dog run in a dirt field .',
#   'a dog chases another dog .',
#   'A yellow dog and a black and white dog are running in the dirt .',
#   'Two dogs are running in a field .',
#   'two dogs running around'],
#  'data\\Images\\1095980313_3c94799968.jpg': ['A little girl in a blue swimsuit is walking along a wooden fence next to a sandy beach .',
#   'A little girl with arms outstretched is posing at the beach .',
#   'A young girl walks on a railing in front of the beach .',
#   'Little girl in blue swimsuit standing on a handrail near a beach .',
#   'The little girl in the blue bathing suit is posing at the beach .'],
#  'data\\Images\\1096097967_ac305887b4.jpg': ['A black and white dog drinking water from a water spray .',
#   'A black and white dog is being soaked with a jet of water in a blue paddling pool .',
#   'A dog sticking its face into the shower from a garden hose .',
#   'A small white dog gets sprayed by water',
#   'A white and black dog is jumping into a pool .'],
#  'data\\Images\\1096165011_cc5eb16aa6.jpg': ['a boy smiles underwater .',
#   'A red-headed boy swimming underwater .',
#   'A small boy swimming underwater',
#   'A smiling boy swims underwater in a pool .',
#   'The boys smiles underwater at the pool .'],
#  'data\\Images\\1096395242_fc69f0ae5a.jpg': ['A boy with a toy gun .',
#   'A little boy in orange shorts playing with a toy .',
#   'A young boy with his foot outstretched aims a toy at the camera in front of a fireplace .',
#   'A young child plays with his new light-up toy .',
#   'Boy with toy gun pointed at the camera .'],
#  'data\\Images\\109671650_f7bbc297fa.jpg': ['A boy in yellow shorts is standing on top of a cliff .',
#   'A boy wearing blue and yellow walking on a cliff edge .',
#   'A little boy standing high in the air on a rock .',
#   'A young child is standing alone on some jagged rocks .',
#   'Child stands near edge of cliff .'],
#  'data\\Images\\109738763_90541ef30d.jpg': ['A person on a snowmobile in mid jump .',
#   'A snowmobiler flies through the air .',
#   'A snowmobile rider flies through the air on his or her machine in front of tall pine trees .',
#   'Rider jumps snowmobile high in rural area .',
#   'The man is up in the air .'],
#  'data\\Images\\109738916_236dc456ac.jpg': ['People are riding around on snowmobiles .',
#   'People pose with helmets and goggles on while riding snowmobiles .',
#   'Several people are taking a break while on a snowmobiling ride .',
#   'Three people and two snowmobiles .',
#   'Two helmeted men sit on yellow snowmobiles while another man stands behind watching .'],
#  'data\\Images\\109823394_83fcb735e1.jpg': ['Three people drive ATVs .',
#   'Three people on ATVs in a brown field turn their heads to look at the camera .',
#   "Three people on ATV 's outside .",
#   "three people on four wheel ATV 's in a field .",
#   'Three people ride their four wheelers through the field .'],
#  'data\\Images\\109823395_6fb423a90f.jpg': ['A four wheeler jumping in an empty field .',
#   'A man on a four wheeler is flying through the air .',
#   'A person is riding an orange ATV in a large empty field .',
#   'Man jumping with all terrain vehicle',
#   'Man on an ATV catching air !'],
#  'data\\Images\\109823397_e35154645f.jpg': ['A man jumps gin the air while riding an ATV',
#   'A man on a four-wheeler jumps near a small building .',
#   'An ATV is airborne over a field in front of a white structure .',
#   'A person dressed in a tan jacket jumps a quad over a harvested cornfield in front of a small out building .',
#   'Man on four wheeler in the air .'],
#  'data\\Images\\1100214449_d10861e633.jpg': ['A boy in s striped shirt is jumping in front of a water fountain .',
#   'A boy is jumping off the side of a running stone water fountain in front of a building .',
#   'A happy boy is jumping in front OD city fountain .',
#   'A little boy is jumping in front of a fountain .',
#   'A little boy is playfully jumping off the side of a fountain .'],
#  'data\\Images\\1104133405_c04a00707f.jpg': ['A boy carrying a soccer ball .',
#   'A boy walks with a ball tucked under his arm .',
#   'A boy walks with a soccer ball near a fence .',
#   'A boy wearing a white t-shirt walks on the grass and carries a soccer ball .',
#   'Small boy carries a soccer ball on a field .'],
#  'data\\Images\\1105959054_9c3a738096.jpg': ['A child painting a picture .',
#   'An artist paints clouds onto a canvas .',
#   'A young girl painting a picture .',
#   'A young girl with braids is painting with water colors on a white paper on the wall .',
#   'The child paints on a large paper with water colors .'],
#  'data\\Images\\110595925_f3395c8bd6.jpg': ['A cyclist is riding a bicycle on a curved road up a hill .',
#   'A man in aerodynamic gear riding a bicycle down a road around a sharp curve .',
#   'A man on a mountain bike is pedaling up a hill .',
#   '"Man bicycle up a road , while cows graze on a hill nearby ."',
#   'The biker is riding around a curve in the road .'],
#  'data\\Images\\1107246521_d16a476380.jpg': ['a black dog jumping to catch a rope toy',
#   'A black dog playing fetch with a ball of rope .',
#   'A black dog pounces to get a rope toy .',
#   'A black dog running after his rope toy .',
#   'A large black dog is playing in a grassy yard .'],
#  'data\\Images\\1107471216_4336c9b328.jpg': ['A little girl is holding a cine camera in front of her face .',
#   'A young girl is looking through an old fashioned video camera .',
#   'A young girl steadies her aim with a camera',
#   'Girl with rosy cheeks and lips holding black toy gun .',
#   'There is a kid with a gun .'],
#  'data\\Images\\1110208841_5bb6806afe.jpg': ['A black and white Border Collie catches a Frisbee in front of an audience .',
#   'a brown and white dog catches a Frisbee in it mouth in front of a group of people .',
#   'A brown and white dug jumping up to catch a Frisbee while an audience watches .',
#   '"A dog jumps to catch a Frisbee , while many people watch ."',
#   'An agile dog catches a Frisbee while a crowd of onlookers watches closely .'],
#  'data\\Images\\1112212364_0c48235fc2.jpg': ['A baby is sitting on and playing with smooth rocks .',
#   'A baby is stacking rocks on the beach .',
#   'A small boy is playing with rocks',
#   'A toddler sitting on a pile of rocks holding a rock at a beach .',
#   'Toddler sits on a pile of rocks .'],
#  'data\\Images\\111497985_38e9f88856.jpg': ['A kid rock climbing against the backdrop of a green valley',
#   'A woman in a striped shirt climbs up a mountain .',
#   'A young man climbs a rocky hill .',
#   'The person has a striped shirt on and is holding on to a rope on a mountain .',
#   'The person in the striped shirt is mountain climbing .'],
#  'data\\Images\\111537217_082a4ba060.jpg': ['A man climbing a rock wall',
#   'A man climbing the side of a cliff .',
#   'A man is rock climbing .',
#   '"Man with red shoes , white shirt and grey pants climbing ."',
#   'The young man with the white t-shirt and jeans is rappeling up the rock wall .'],
#  'data\\Images\\111537222_07e56d5a30.jpg': ['A climber wearing a blue helmet and headlamp is attached to a rope on the rock face .',
#   'A man climbs a rocky wall .',
#   'a rock climber climbs a large rock .',
#   'A woman in purple snakeskin pants climbs a rock .',
#   'Person with blue helmet and purple pants is rock climbing .'],
#  'data\\Images\\1115565519_d976d4b1f1.jpg': ['A child playing with a fountain at the beach .',
#   'A child plays with a fountain .',
#   'A girl looks at a fountain that sprays water .',
#   'A little girl playing in water on a frog sculpture .',
#   'The little girl is playing with a toy in a public fountain .'],
#  'data\\Images\\1115679311_245eff2f4b.jpg': ['A black dog is jumping over a log along a beach .',
#   'A black dog runs along the beach and jumps over a wood barrior .',
#   'A dog is running on the beach .',
#   'a dog jumping over a small wall at a beach near the water .',
#   'An animal is running on the beach .'],
#  'data\\Images\\111766423_4522d36e56.jpg': ["A black and white bird eating seeds out of someone 's hand",
#   'A black and white bird standing on a hand .',
#   "A small bird sits in a person 's hand and eats seeds .",
#   'Black and white bird standing on hand of someone holding sunflower seeds',
#   'The small bird is clinging to a finger of the hand holding the seeds .'],
#  'data\\Images\\1117972841_2b9261f95f.jpg': ['A brown dog is running in the sand .',
#   'A brown dog playing in the sand .',
#   'A brown dog plays at the beach .',
#   'A dog is standing in the sand .',
#   'A dog running fast in the sand .'],
#  'data\\Images\\1118557877_736f339752.jpg': ['A little boy stands in the surf .',
#   'A small child wades through the water while being guided by another person .',
#   'A young boy laughs while splashing in the ocean .',
#   'a young boy wearing a colorful bathing suit splashing in the ocean',
#   'A young child splashing in water .'],
#  'data\\Images\\1119015538_e8e796281e.jpg': ['A little tan dog with large ears running through the grass .',
#   'A playful dog is running through the grass .',
#   'A small dogs ears stick up as it runs in the grass .',
#   'The small dog is running across the lawn .',
#   'this is a small beige dog running through a grassy field'],
#  'data\\Images\\1119418776_58e4b93eac.jpg': ['A black and white dog is running through the field .',
#   '"A black , brown and white dog running through a field ."',
#   '"A brown , black and white dog is running through a large field with its mouth open ."',
#   'A dog running in a field .',
#   'A dog with its mouth open running through a field torwards the camera .'],
#  'data\\Images\\1119463452_69d4eecd08.jpg': ['A girl in a pink swimsuit in a pool',
#   'A girl swimming in a pool .',
#   'A little girl in a pink bathing suit swimming in a pool .',
#   'A little girl swimming in a pool .',
#   'Smiling little girl swimming in outdoor pool .'],
#  'data\\Images\\1121416483_c7902d0d49.jpg': ['A child is standing on her head .',
#   'A little girl standing on her head .',
#   'A small child doing a handstand on a bed .',
#   'A young girl does a handstand on a bed with blue sheets .',
#   'The girl is upside down on a bed'],
#  'data\\Images\\112178718_87270d9b4d.jpg': ['A guy stands in the sand with a snowboard behind him .',
#   'A man holds a surfboard on the beach .',
#   'a man holds his snowboard in the sand .',
#   'A man with his surfboard stands in the sand .',
#   'Man is standing on white sand and holding a snowboard .'],
#  'data\\Images\\112243673_fd68255217.jpg': ['People on ATVs and dirt bikes are traveling along a worn path in a field surrounded by trees .',
#   "Three people are riding around on ATV 's and motorcycles .",
#   'Three people on motorbikes follow a trail through dry grass .',
#   'Three people on two dirt-bikes and one four-wheeler are riding through brown grass .',
#   'Three people ride off-road bikes through a field surrounded by trees .'],
#  'data\\Images\\1122944218_8eb3607403.jpg': ['A baby in a white garment holds a flag with crescent moon and star .',
#   'A baby is holding a small black flag with a moon and a star on it .',
#   'A baby wearing a white gown waves a Muslim flag .',
#   'A little toddler dressed in white is smiling while a lady helps him wave a flag .',
#   'Baby in white outfit holding black and white flag .'],
#  'data\\Images\\1124448967_2221af8dc5.jpg': ['A half naked man is sleeping on his chair outdoors .',
#   'An older man sits back and relaxes on a patio outside an adobe building where many bicycles are propped .',
#   '"A shirtless man in a white cap relaxes in a deck chair , close to three parked bicycles ."',
#   'Man relaxing in a folding chair on the street .',
#   '"Topless old man wearing slippers , navy blue pants and a white hat while reclining in a chair outside ."'],
#  'data\\Images\\1129704496_4a61441f2c.jpg': ['A brown and white and a black and white dog hauling in a floating toy from the ocean .',
#   'Both dogs retrieve the play toy from the water .',
#   'Two dogs in the ocean playing with a toy',
#   'Two dogs run through the water with a rope in their mouths .',
#   'Two dogs tug at a chew toy in the surf .'],
#  'data\\Images\\1130017585_1a219257ac.jpg': ['"There are three young people , one dark haired holding a bottled drink , one with head tilted back and finger in her mouth , and one with spiked hair ."',
#   'The young people party in the streets .',
#   'Three girls make faces as one takes a drink while they stand in a busy street .',
#   'Three women on the street drinking and posing',
#   'Three young women pose for the camera at a parade .'],
#  'data\\Images\\1130369873_d80a1aa59c.jpg': ['A brown dog is running through neck-deep water carrying a tennis ball .',
#   'A brown dog splashes in the water while carrying a ball in its mouth .',
#   'A brown dog swims through water outdoors with a tennis ball in its mouth .',
#   '"A red dog , holding a ball , splashes through vegetation filled water ."',
#   '"Brown dog with tennis ball in mouth , in water and bushes ."'],
#  'data\\Images\\1130401779_8c30182e3e.jpg': ['Two brown dogs are creating large splashes as they run in a river .',
#   'Two brown dogs in the water .',
#   'Two brown dogs running through water .',
#   'Two brown dogs runs through the water .',
#   'Two dogs splash through the water .'],
#  'data\\Images\\1131155939_b4b457b05e.jpg': ['A black dog runs into the ocean next to a pile of seaweed .',
#   '"A black lav runs into the water on the beach , with swimmers in the distance and sea kelp in the foreground ."',
#   '"A dog at the shore of an ocean , with seaweed in foreground ."',
#   'A dog is running in the waves at the beach .',
#   '"A pile of seaweed sits on the sand , behind it a big black dog is running in the water ."'],
#  'data\\Images\\1131340021_83f46b150a.jpg': ['A young boy runs while wearing sandals .',
#   'Little boy in a striped shirt and brown shorts is running .',
#   '"The little boy , in a short sleeved shirt and shorts , is running outside ."',
#   'The little boy is wearing a black pinstripe shirt and walking on a deck .',
#   'Young boy running outside on the pavement .'],
#  'data\\Images\\1131800850_89c7ffd477.jpg': ['A brown and white dog stands outside while it snows .',
#   'A dog is looking at something near the water .',
#   'A furry dog attempts to dry itself by shaking the water off its coat .',
#   'A white and brown dog shaking its self dry .',
#   'The large brown and white dog shakes off water .'],
#  'data\\Images\\1131804997_177c3c0640.jpg': ['Two men are sitting on the ground and going through their backpacks .',
#   'Two men sitting in front of a railing are looking at something .',
#   'Two men with backpacks placed in front of them sitting in front of a railing .',
#   'Two men with backpacks are sitting on cardboard along a railing .',
#   'Two older men with backpacks sit at a bus station .'],
#  'data\\Images\\1131932671_c8d17751b3.jpg': ['A boy is jumping on a bed .',
#   'A boy jumped up from the green bed .',
#   'A boy jumps from one bed to another .',
#   'A small child is jumping on a bed .',
#   'The boy in blue shorts is bouncing on the bed .'],
#  'data\\Images\\1132772170_600610c5df.jpg': ['A child leaping from bed to bed behind the back of a man .',
#   'A man is standing with his arms folded looking at something while the person behind him is jumping onto one of the two beds in the room .',
#   'a man wearing a yellow shirt standing in the middle of two beds that a boy is jumping on in the background',
#   'A young child jumping on the bed as a man looks the other way .',
#   'Man standing in the bedroom with little boy jumping into bed .'],
#  'data\\Images\\113678030_87a6a6e42e.jpg': ['A snowboarder sits on a slope with skiers and boarders nearby .',
#   'A snowboarder takes a rest on the mountainside .',
#   'Snowboarders sitting in the snow while skiers take the hill .',
#   'The snowboarder is sitting down .',
#   '"Two skiers stand , two sit on slopes ."'],
#  'data\\Images\\1138784872_69ade3f2ab.jpg': ['A girl in green walks down a city street .',
#   'A small child in green clothing walks past a store opening and a woman in pink pants .',
#   'A small child walks down a sidewalk .',
#   'A young boy is walking in front of some stores',
#   'The child in the green one piece suit is walking past a store window .'],
#  'data\\Images\\114051287_dd85625a04.jpg': ['A boy dressed in soccer attire and holding his shoes getting out of a car .',
#   'A boy in a red soccer strip is holding his boots in his hand whilst stepping out of a car .',
#   'A boy in glasses is wearing a red shirt .',
#   'A child getting out of the car wearing soccer shoes .',
#   'A young boy gets out of the van and prepares his shoes for wear during a soccer game .'],
#  'data\\Images\\1141718391_24164bf1b1.jpg': ['"A bridge through high green plants , a man and a woman on it ."',
#   'A man and a woman are crossing over a rope bridge with greenery all over them .',
#   'A man and a woman are walking across a rope bridge .',
#   'A man and a woman crossing a suspension bridge in a tropical setting .',
#   'Woman and man walking across wooden rope bridge with a caution sign beside it .'],
#  'data\\Images\\1141739219_2c47195e4c.jpg': ['A family gathered at a painted van',
#   'A girl climbing down from the side of a bright blue truck while others watch .',
#   'A man is helping a girl step down from a colorful truck whilst a woman and three children watch .',
#   'A very colorful bus is pulled off to the side of the road as its passengers load .',
#   'Two women and four children standing next to a brightly painted truck .'],
#  'data\\Images\\1142283988_6b227c5231.jpg': ['A blond woman poses with a person in a pink costume .',
#   'A smiling woman holds a person dressed in a pig costume .',
#   "A young woman hugs a young man who 's wearing a pink costume .",
#   '"Blond embracing young man in pink costume , at event"',
#   'Two people are hugging and one is wearing a pink-hooded stretch top .'],
#  'data\\Images\\1142847777_2a0c1c2551.jpg': ['A bicyclist riding on a city street .',
#   'A woman in a blue helmet and brown shorts rides her bike on a busy street .',
#   'A woman is riding a blue bike .',
#   'A woman is riding her bicycle in traffic',
#   'A woman wearing a blue helmet rides her bicycle in a parking lot .'],
#  'data\\Images\\1143373711_2e90b7b799.jpg': ['A bicycle rider is crossing a street .',
#   'A bicyclist getting ready to cross a street .',
#   'A biker in spandex riding on a busy street .',
#   'A man in blue and white biking gear rides down a busy street .',
#   'a man wearing a helmet riding his bicycle down the street .'],
#  'data\\Images\\1143882946_1898d2eeb9.jpg': ['A lady wearing a helmet holding a bike .',
#   'A woman in a blue vest and a sky blue helmet stands with her bicycle in traffic .',
#   'A woman in a helmet rides her bike behind a car .',
#   'A woman with a helmet and a backpack walks next to her bike .',
# ...
#   'A girl in a white puffy jacket takes a picture .',
#   'a group of people looking into their cameras',
#   'Asian woman in white coat takes photo .',
#   'The woman in the white coat is holding a camera in her hand .'],
#  'data\\Images\\2086532897_b8714f2237.jpg': ['A kayaker falling down a waterfall',
#   'A man is kayaking down a waterfall .',
#   'A man on a kayak coming down a raging waterfall',
#   'A person is on a small boat and going down some very strong water currents .',
#   'White water rafter goes through a rough spot .'],
#  'data\\Images\\2086534745_1e4ab80078.jpg': ['A man in a yellow boat paddling down rough waters .',
#   'A rafter in a yellow raft in a steamy white river .',
#   'A yellow kayak is descending quickly down a white water rapid .',
#   'Kayacker riding rough current downstream .',
#   'The yellow kayak is in the middle of the rapids .'],
#  'data\\Images\\2086678529_b3301c2d71.jpg': ['A girl in a purple dress smiling as she climbs an indoor rock wall .',
#   'A girl is in a dress .',
#   'A little girl wearing a purple dress looks down at the camera .',
#   '"a young girl climbs a rock wall , in a purple dress ."',
#   'A young girl wears a purple dress .'],
#  'data\\Images\\2087317114_cf06df5aa5.jpg': ['A Mani is kayaking down some calmer rapids .',
#   'A man in a small kayak is floating down the river .',
#   'A man in a yellow jacket is floating on the river in a green kayak .',
#   'A man smiles in his blue and green kayak .',
#   'A man wearing a helmet in a Pyranha kayak floats down some river rapids .'],
#  'data\\Images\\2087640654_1a84577a44.jpg': ['A blonde dog is digging a deep hole in the ground and its tail is up in the air .',
#   'A dog half way in a hole in the ground .',
#   'A dog is digging a large hole in a yard to find something .',
#   'A dog is digging in the ground and half of his body is under the ground .',
#   'The rear end of an animal whose front end is underground .'],
#  'data\\Images\\2088120475_d6318364f5.jpg': ['A person dressed up as a snowman is walking through a crowd of people .',
#   '"five cold people in the snowstorm , one wearing a snowman head"',
#   'People pose for a picture in the snow',
#   'Three young people pose by a snowman in a red tie .',
#   'Two couples pose with a snowman .'],
#  'data\\Images\\2088460083_42ee8a595a.jpg': ['A broken down hummer gets towed on a truck bed .',
#   'A damaged vehicle is carried by a repair truck in a night-time scene .',
#   'A flat bed truck in a parking lot with an army vehicle on its bed .',
#   '"An old , beat-up jeep being towed away ."',
#   'Dirty SUV sits on the bed of a tow truck at night .'],
#  'data\\Images\\2088532947_c628e44c4a.jpg': ['The girl in the white shirt has a bracelet on and has her arm around the girl in the peach shirt .',
#   'The two girls laid on the grass together .',
#   'Two little girls are laying on the grass smiling .',
#   'two young girls holding each other on the grassy ground',
#   'two young girls hug each other in the grass .'],
#  'data\\Images\\2088910854_c6f8d4f5f9.jpg': ['A large man is wearing a headband with mistletoe attached to it .',
#   'A man in a sweatshirt and cap wears a flower on his head .',
#   'A man wearing a black knit cap with a red and white striped headband with a flower on top .',
#   'An man with a black ski cap and a red and white headband looks into the distance .',
#   'Man wearing a black hat with a christmas theme .'],
#  'data\\Images\\2089122314_40d5739aef.jpg': ['A dog running with a newspaper in its mouth .',
#   '"A dog runs down the street , carrying a newspaper ."',
#   'A dog with a newspaper in his mouth runs down a paved path .',
#   '"A fluffy , tri-colored dog is running down the road with a paper in its mouth ."',
#   'An Australian shepherd dog carrying a newspaper in his mouth .'],
#  'data\\Images\\2089350172_dc2cf9fcf6.jpg': ['"three black dogs are swimming through some murky brown water , one with a yellow object in its mouth ."',
#   'three black dogs swimming in dirty water',
#   'Three dark dogs swimming and one of them has a ball .',
#   'Three dogs are up to their necks in water .',
#   'Three dogs swim in the water .'],
#  'data\\Images\\2089426086_7acc98a3a8.jpg': ['A girl in a hooded jacket presents a cake with candles .',
#   'A girl in a hood jacket holds a birthday cake with many candles .',
#   'A girl in a winter coat with a birthday cake .',
#   'A girl is holding a birthday cake .',
#   'A young girl holding a cake with candles dressed in a heavy coat .'],
#  'data\\Images\\2089442007_6fc798548c.jpg': ['A brown dog is walking in the water .',
#   'A brown dog takes cautious steps in the calm waters with a sandy bottom .',
#   'A brown dog wades in the water .',
#   'A dog with red fur stands in a body of water .',
#   '"A large , golden colored dog is walking through water ."'],
#  'data\\Images\\2089539651_9e518ec7de.jpg': ['A hiker with two hiking poles stands on a hillside with a view of the city below him .',
#   'A hiker with two sticks is a standing on a path that is high up on a hill .',
#   'A hiking man stands on a cliff overlooking a city .',
#   'A man hikes on a dirt path high above a city .',
#   'A person holding poles is standing on a rock ledge with bushes on each side overlooking mountains .'],
#  'data\\Images\\2089542487_b4c1ee7025.jpg': ['A hiker is ready to take on a rugged outdoor trail .',
#   'a lone hiker on a dirt hiking trail with a hat and sunglasses on with trees in the background',
#   'A man in shorts is hiking in a dry region .',
#   'A man stops for a picture with the scenery during his hike .',
#   '"The man is posing for a picture in the desert wearing a green shirt and hat , and holding a metal detector ."'],
#  'data\\Images\\2089555297_95cf001fa7.jpg': ['A man in a hat with long sleeves and long pants stands overlooking a city .',
#   'A man stands on a cliff overlooking a city .',
#   'A man with a backpack and hat is standing by a high cliff where you can see for miles .',
#   'Hiker standing on top of a rock overlooking a town .',
#   '"The man wearing a backpack and a hat , stands on a ledge overlooking a city ."'],
#  'data\\Images\\2090327868_9f99e2740d.jpg': ['"A woman , a little boy , and a tiny baby are standing in front of a cow statue ."',
#   'a woman and two small children posing in front of a large cow statue .',
#   'A woman gives a baby to a small child to hold as they stand in front of a cow statue .',
#   'A woman stands with two children near a decorated bull statue .',
#   'The woman and children are standing next to a statue of a cow .'],
#  'data\\Images\\2090339522_d30d2436f9.jpg': ['A man in a green hat is someplace up high .',
#   'A man in a green hat is taking a self portrait .',
#   'A man in a hat at a scenic overlook .',
#   'a man wearing a green canvas hat with a distnat city in the background',
#   'Man with green hate and sunglasses on a high up peak'],
#  'data\\Images\\2090386465_b6ebb7df2c.jpg': ['A woman and man in winter gear stand .',
#   'Three adults wearing cold weather gear .',
#   'Two people are wearing heavy clothing .',
#   'Two people in winter clothing .',
#   'two women bundled up on a snowy day'],
#  'data\\Images\\2090387793_274ab4cf7d.jpg': ['A boy wearing black walks down the street with his hands in fists .',
#   'A teenage boy dressed in black stands on a snowy street .',
#   'A teenage boy wearing all black tries to look tough with cheap jewelry on .',
#   'A young man wearing a black hat and jacket is walking outside .',
#   'Punk rock teenager walks with a mean look on his face .'],
#  'data\\Images\\2090545563_a4e66ec76b.jpg': ['the boy laying face down on a skateboard is being pushed along the ground by another boy .',
#   'Two girls play on a skateboard in a courtyard .',
#   'Two people play on a long skateboard .',
#   'Two small children in red shirts playing on a skateboard .',
#   'two young children on a skateboard going across a sidewalk'],
#  'data\\Images\\2090723611_318031cfa5.jpg': ['Dogs walking in the grassy field .',
#   'Large fluffy grey dog standing in grass in front of a brown dog .',
#   'one dog standing in some grass with his tongue hanging out and a tan dog in the background',
#   'Two dogs of different breeds are standing in a pasture .',
#   'Two dogs stand in the grass .'],
#  'data\\Images\\2090997177_76d482b158.jpg': ['A black dog bounds across the sand .',
#   'A dog walking across the desert .',
#   'A short black dog is walking over a barren landscape .',
#   'A small black dog running across the sand .',
#   'A small black dog walks in the sand .'],
#  'data\\Images\\2091171488_c8512fec76.jpg': ['A female wearing pink gloves and a brown jacket is smiling in the snow .',
#   'A woman standing in the snow with people in the background .',
#   'A young woman in a spring coat and purple gloves stands in falling snow .',
#   'A young woman looks happy in winter clothes while it snows .',
#   'Young asian woman with pink gloves stands in the snow .'],
#  'data\\Images\\2092177624_13ab757e8b.jpg': ['A boy in african clothing runs across a concrete wall .',
#   'A little boy with a green shirt is running on a rock ledge .',
#   'An African boy in large green shirt is running barefoot along a wall .',
#   '"A young boy dressed in green running along a smooth , stone wall near a wooded area ."',
#   'Boy in green tunic on rock wall .'],
#  'data\\Images\\2092419948_eea8001d0f.jpg': ['A long haired man walking away beside a canal whist holding onto a railing .',
#   'A man walks down a path next to a waterway .',
#   'A person walks by some blue-green water while holding a rail .',
#   'a person with a long ponytail walks along a waterway under a tunnel',
#   'The man with long hair is walking along a storm drain .'],
#  'data\\Images\\2092870249_90e3f1855b.jpg': ['A man lies on a street with his head and shoulders under a parked car that is jacked up .',
#   'A man looks under a car on a wet street .',
#   'A man works on a car .',
#   '"A person lies half under a car , face-down ."',
#   'A person underneath a car with a jack .'],
#  'data\\Images\\2094323311_27d58b1513.jpg': ["A dog places his head on a man 's face .",
#   'A dog snuggles with a man in sunglasses .',
#   "A dog with a blue collar is licking a man who 's wearing large tinted sunglasses .",
#   "A large brown dog with a blue collar is resting his chin on a man 's face .",
#   'An orange dog is licking a man wearing red sunglasses .'],
#  'data\\Images\\2094543127_46d2f1fedf.jpg': ["A girl holding a crocodile 's mouth closed",
#   'A girl is posed over a statue of a dangerous animal .',
#   'A girl sits on what appears to be a crocodile .',
#   'A girl sitting on top of a crocodile',
#   'A girl with red hair is sitting on a crocodile holding its jaw .'],
#  'data\\Images\\2094810449_f8df9dcdf7.jpg': ['A boy stands in the ocean lifting up his shorts .',
#   'A child in blue shorts is standing ankle deep in the water .',
#   '"A little boy in blue shorts , glasses , and a coat stands in the surf ."',
#   'The kid is wearing a blue jacket and standing in shallow beach water .',
#   'The small child wades ankle deep in the water on the shoreline .'],
#  'data\\Images\\2095007523_591f255708.jpg': ['A baby looks through his crib .',
#   '"A baby , surrounded by some toys , looks out of a playpen ."',
#   'Baby in playpen with wide eyes',
#   'Baby looking through playpen bars at camera .',
#   '"The infant is laying on its stomach , in a crib , looking up at the camera ."'],
#  'data\\Images\\2095078658_c14ba89bc2.jpg': ['A dog runs through snow in front of the woods .',
#   'Large dog running in snow',
#   'The dog runs through the snow .',
#   'The German shepherd dog is running through the snow .',
#   'The German Shepherd is running through the white snow .'],
#  'data\\Images\\2095435987_1b7591d214.jpg': ['A dog lying on its back in the sand .',
#   'A white and brown dog rolls on its back in the sand .',
#   'The dog rolls over to scratch its back in the sand .',
#   'The white and brown dog is rolling in the sand .',
#   'The white dog is on its back in the sand with paws in the air .'],
#  'data\\Images\\2095444126_201ff9f222.jpg': ['A dog is shaking off water .',
#   'A dog shakes his head .',
#   'A dog shakes off water',
#   'A dog shakes off water and gets contorted .',
#   'The dog is shaking water off of his body .'],
#  'data\\Images\\2095478050_736c4d2d28.jpg': ['A man and a boy play music as little girls watch .',
#   'A man is playing a guitar with a child playing a harmonica while three young girls watch .',
#   'Three children watch a man onstage playing guitar .',
#   'Three little girls look on as a boy plays the harmonica with an adult guiutarist sitting beside him .',
#   'Three little girls watch a band .'],
#  'data\\Images\\209605542_ca9cc52e7b.jpg': ['a climber wearing a red headband is pulling himself up some grey rocks high above some green foliage .',
#   'A man in a headband climbing a rock .',
#   'a man with a red headband climbing a rock cliff looming over greenery .',
#   'Man climbing a sheet rock face .',
#   'Man in red headband climbing a rock'],
#  'data\\Images\\2096771662_984441d20d.jpg': ['a man looks through his binoculars while another man holds a drink .',
#   'A man with a thermos is standing next to a man who is gazing through binoculars .',
#   'Two men are standing together while one looks through binoculars .',
#   'Two men look out as one is holding binoculars .',
#   'two people standing next to each other with mountains in the distance .'],
#  'data\\Images\\2097398349_ff178b3f1b.jpg': ['A hiker waves to the camera as he standing in front of snowcapped mountains .',
#   'A man stands on the snow near the mountains .',
#   'A person poses in the snow .',
#   '"A person stands in the snow at the top of a mountian , arms raised ."',
#   'A skier in the mountains .'],
#  'data\\Images\\2097403787_77a154f5b9.jpg': ['a lone person standing on some rocks with large snowy mountains in the background .',
#   'A man is standing on the rocky ground in front of the mountain .',
#   'A man standing in front of an icy mountain .',
#   'The person is standing by the water in front of the snow topped mountains .',
#   'The traveller pauses in front of the mountain view .'],
#  'data\\Images\\2097407245_c798e0dcaf.jpg': ['A man in a winter jacket and knit cap stand with his arms up at his side in a snow landscape .',
#   'A man is standing on dirt with his hands in the air with mountains and snow behind him .',
#   'A man raises his arms on rocky beach .',
#   'One lone man with fist in the air with large rocky mountains in the background',
#   'Man with outstretched arms standing on snow-covered rocks .'],
#  'data\\Images\\2097420505_439f63c863.jpg': ['A male hiker wearing a green jacket is posing next to a large glacier .',
#   'A man with a camera and an ice structure behind him .',
#   'A man with a camera crouching on ice .',
#   'A man with a camera kneels in front of a giant hill of snow .',
#   'The mountain climber prepares to take a photo .'],
#  'data\\Images\\2097489021_ca1b9f5c3b.jpg': ['A girl in a ballet fairy costume is touched by a wand .',
#   'A young girl performing the nutcracker .',
#   'The little girl is standing on a stage dressed up as a pink fairy .',
#   '"The tiny girl dressed in a butterfly ballet costume , waves her wand near a nutcracker statue ."',
#   'Young girl waving turquiose leotard and pink tutu with wings waving wand .'],
#  'data\\Images\\2098174172_e57d86ea03.jpg': ['A hiker is posing in front of snowy mountains .',
#   'A hiker is standing in before the mountain holding two walking sticks .',
#   'A man stands in front of snow covered mountains .',
#   'A man with two ski poles stands near a mountaintop .',
#   'The man wears a green hat and jacket while standing in front of a mountain .'],
#  'data\\Images\\2098418613_85a0c9afea.jpg': ['A brown chow mix dog is standing in front of a van with euro plats in the middle of a messy yard .',
#   'A brown dog standing in a muddy yard .',
#   'A brown dogs walks near a green van and some junk .',
#   'A large brown dog stands in front of a green van in the yard of a house .',
#   'A yellow dog is standing in front of a green car and next to a toilet .'],
#  ...}

# %%
images = list(image_captions.keys())
captions = list(image_captions.values())
train_images, test_images, train_captions, test_captions = train_test_split(images, captions, test_size=0.2, random_state=42)

# %%
train_images
# Out:
# ['data\\Images\\3393152604_27bd1037f2.jpg',
#  'data\\Images\\3549673305_4dfd44e04a.jpg',
#  'data\\Images\\3181328245_7c04ce1691.jpg',
#  'data\\Images\\2393410666_b8c20fff61.jpg',
#  'data\\Images\\239807547_4923efc821.jpg',
#  'data\\Images\\1388373425_3c72b56639.jpg',
#  'data\\Images\\3561543598_3c1b572f9b.jpg',
#  'data\\Images\\3477369101_8e0c61d8f4.jpg',
#  'data\\Images\\3564385317_1bf5094068.jpg',
#  'data\\Images\\2607383384_d9ce9de793.jpg',
#  'data\\Images\\3033686219_452b172ab0.jpg',
#  'data\\Images\\399246804_b4b5dc70e1.jpg',
#  'data\\Images\\2911552402_5166bc173b.jpg',
#  'data\\Images\\3399312265_9c74378692.jpg',
#  'data\\Images\\3014015906_fdba461f36.jpg',
#  'data\\Images\\3171347658_f0d5469c56.jpg',
#  'data\\Images\\2602306033_2b3100d36b.jpg',
#  'data\\Images\\3259991972_fce3ab18b2.jpg',
#  'data\\Images\\2394763838_99d1435b85.jpg',
#  'data\\Images\\3090386315_87ed417814.jpg',
#  'data\\Images\\3428386573_670f5362f0.jpg',
#  'data\\Images\\2195620255_6693479734.jpg',
#  'data\\Images\\3077166963_fe172c709d.jpg',
#  'data\\Images\\576920249_df1bdc2068.jpg',
#  'data\\Images\\3472485022_5d03e9852d.jpg',
#  'data\\Images\\3537474810_cf676b3259.jpg',
#  'data\\Images\\766346887_a9a9d0637a.jpg',
#  'data\\Images\\1164765687_7aca07bbe7.jpg',
#  'data\\Images\\207275121_ee4dfa0bf2.jpg',
#  'data\\Images\\2245916742_73af13c733.jpg',
#  'data\\Images\\2925242998_9e0db9b4a2.jpg',
#  'data\\Images\\823697339_aadbeef495.jpg',
#  'data\\Images\\3511890331_6163612bb9.jpg',
#  'data\\Images\\3259666643_ae49524c81.jpg',
#  'data\\Images\\58363930_0544844edd.jpg',
#  'data\\Images\\2273105617_7c73d2d2d3.jpg',
#  'data\\Images\\2643263887_a32ffb878f.jpg',
#  'data\\Images\\1225443522_1633e7121f.jpg',
#  'data\\Images\\3522349685_f046f0e250.jpg',
#  'data\\Images\\2894576909_99c85fd7a7.jpg',
#  'data\\Images\\801607443_f15956d1ce.jpg',
#  'data\\Images\\260828892_7925d27865.jpg',
#  'data\\Images\\1445123245_c7b9db0e0c.jpg',
#  'data\\Images\\2089426086_7acc98a3a8.jpg',
#  'data\\Images\\3562302012_0cbcd01ff9.jpg',
#  'data\\Images\\3373243733_9aba7740ed.jpg',
#  'data\\Images\\1248953128_24c9f8d924.jpg',
#  'data\\Images\\2460159430_71ab1aacfa.jpg',
#  'data\\Images\\2064790732_219e52e19c.jpg',
#  'data\\Images\\3533660418_f3a73a257c.jpg',
#  'data\\Images\\3411022255_210eefc375.jpg',
#  'data\\Images\\3296150666_aae2f64348.jpg',
#  'data\\Images\\241346105_c1c860db0d.jpg',
#  ...]

# %%
train_data = dict(zip(train_images, train_captions))

# Convert test set back into dictionary
test_data = dict(zip(test_images, test_captions))

# %%
train_data
# Out:
# {'data\\Images\\3393152604_27bd1037f2.jpg': ['A bulldog jumps over a log next to a stream .',
#   'A dog is pawing at a fallen log nearby a stream in an area with pinestraw .',
#   'Black and white dog grabs tree limb',
#   'The black and white dog jumps by a log near a creek .',
#   'The dog plays with the large log .'],
#  'data\\Images\\3549673305_4dfd44e04a.jpg': ['A couple kissing on the neck on a busy street .',
#   'A man embraces a woman on a crowded street .',
#   'A man in a leather jacket with the collar popped kisses the neck of a woman in a gray coat wearing a white scarf .',
#   'Man kisses girl on neck',
#   "Man kissing a woman 's neck on a busy sidewalk ."],
#  'data\\Images\\3181328245_7c04ce1691.jpg': ['Two babies are sitting in a play mat .',
#   'two babies playing inside of a colorful padded enclosure .',
#   'Two children sit inside a play area .',
#   'Two toddlers are sitting in a colorful playpen .',
#   'Two toddlers are sitting in a plastic playpen with a blue floor .'],
#  'data\\Images\\2393410666_b8c20fff61.jpg': ['A black dog wearing a blue shirt is jumping in the air',
#   'A dog wearing a blue shirt is running and jumping through the air .',
#   'A dog with a blue blanket runs through the grass .',
#   'A dog with a muzzle and blue jacket runs around the yard .',
#   'The black greyhound dog is running on the grass wearing a blue jacket .'],
#  'data\\Images\\239807547_4923efc821.jpg': ['two dogs fight next to rocks',
#   'Two dogs playfully wrestle in a rocky setting .',
#   'Two dogs playing next to rocks .',
#   'two dogs play on the dry ground .',
#   "Two dogs sit in the shade and lick each other 's face ."],
#  'data\\Images\\1388373425_3c72b56639.jpg': ['A woman in a black shirt is sitting next to a florescent green bag .',
#   'A woman sits on a stone wall and talks on her phone .',
#   'A woman speaks on her cellphone with her purse and a yellow bag on the ledge next to her .',
#   'A woman with a backpack sitting outside a building with others .',
#   'This woman is smiling and talking on the phone while sitting on a stone wall .'],
#  'data\\Images\\3561543598_3c1b572f9b.jpg': ['A group of men wearing uniforms with hats gather holding flags .',
#   'A VFW group stand at attention at a funeral .',
#   'Members of a fraternal organization in a graveyard',
#   'Men in uniform take part in a ceremony with flags .',
#   '"Men in uniform , with flags , are gathered outdoors for a ceremony ."'],
#  'data\\Images\\3477369101_8e0c61d8f4.jpg': ['A black dog lying on its back in green grass .',
#   'A black dog rolling in grass .',
#   'A dog rolling around in the grass .',
#   'Dog rolling in grass',
#   'The black and brown dog is rolling in the grass .'],
#  'data\\Images\\3564385317_1bf5094068.jpg': ['A man does Ti Chi on a rock overlooking a forest .',
#   'A man stands in a strange position on a rock high above some trees .',
#   'A person dances along a high rock surface nearby the tops of tree-lined areas .',
#   'a person dances on a rock .',
#   'This hiker does a dance of joy on top of the mountain .'],
#  'data\\Images\\2766926202_4201bf2bf9.jpg': ['Two children playing with fireworks in shallow water',
#   'Two children wearing glow necklaces play with sparklers while standing in water .',
#   'Two men are playing with glow sticks and sparklers .',
#   'Two men play with fireworks on the beach .',
#   '"Two people are standing in shallow water , waving sparklers around"'],
#  'data\\Images\\3394750987_a32ecc477e.jpg': ['A boy on a skateboard grinding down a handrail .',
#   'A boy skateboards down the metal handrail at night .',
#   'A man is skateboarding down a railing on some stairs .',
#   'A skateboarder slides down a metal railing .',
#   'A young boy does skateboarding tricks down metal stairs .'],
#  'data\\Images\\441921713_1cafc7d7d2.jpg': ['a bird lands on a mans glove .',
#   'A man holds a bird .',
#   'A man holds a falcon on his arm .',
#   'Gloved man holding a bird of prey .',
#   'The man is wearing gloves and holding a hawk in his hands .'],
#  'data\\Images\\2403376030_903521c371.jpg': ['A dog and its owner takes a run .',
#   'A woman in a black hooded sweatshirt walking with a large dog .',
#   'A woman in a black sweatshirt is walking on a dock with a wet dog .',
#   'A woman walks a dog down a wooden path .',
#   'The girl with the black T-shirt is out with a large brown dog .'],
#  'data\\Images\\2635905544_dbc65d0622.jpg': ['Two brown dogs playfully chase a red and white soccer ball .',
#   'Two dogs are playing with a red and white ball',
#   'Two small dogs chasing a red striped ball .',
#   'Two small dogs playing in a grassy area with a large white and red striped ball .',
#   'Two small dogs playing with a volleyball'],
#  'data\\Images\\270809922_043e3bef06.jpg': ['a lone man climbing high on a snowy mountain .',
#   'A man is standing on top of a glacier .',
#   'A man standing on a mountainside in snow .',
#   'A mountain climber posing in the snow .',
#   'A person walking up a snow covered mountain on a bright day .'],
#  'data\\Images\\597543181_6a85ef4c17.jpg': ['A boy plays on a green swing .',
#   'A small boy in a swing .',
#   'A small child smiles while swinging inside a green playground toy .',
#   'A young boy smiles as he rides the swing .',
#   'a young child swinging on a green swing .'],
#  'data\\Images\\3482974845_db4f16befa.jpg': ['A black dog with his pink tongue sticking out running on the beach with a white dog wearing a red collar .',
#   'A white dog is following a black dog along the beach .',
#   'Two dogs run across the barren ground .',
#   'Two dogs running on the beach .',
#   'Two terrier dogs frolic on the beach .'],
#  'data\\Images\\2874728371_ccd6db87f3.jpg': ['A large brown dog and a small black dog stand near each other on a dirt patch surrounding by grass and weeds .',
#   'A large brown dog and a small grey dog on a rocky surface with weeds behind them .',
#   'A large brown dog has his noce on the back of a small black dog .',
#   'A small black dog is shocked when a larger brown dog gives him a sniff .',
#   'The brown dog sniffs the back of a smaller black dog .'],
#  'data\\Images\\2913965136_2d00136697.jpg': ['A boy in a green uniform is kicking a soccer ball in a game while two others stand behind him .',
#   'Boys play soccer near a goal post .',
#   'Some children are playing soccer on a sports-field by the goal .',
#   'The little boy gets ready to kick the soccer ball .',
#   'three boys play soccer .'],
#  'data\\Images\\241347689_d0b1ac297d.jpg': ['african Americans play football .',
#   'A group of football players in red and white uniforms .',
#   'a large group of football players sitting on a field wearing red and white jerseys .',
#   'Many football players sitting on the ground .',
#   '"Two men in football uniforms sit on the grass , looking unhappy ."'],
#  'data\\Images\\2272750492_91e8f67328.jpg': ['A man jumps through the air while snowboarding .',
#   'A snowboarder in gray pants and a white jacket catches some air .',
#   'A snowboarder in gray pants is doing a jump .',
#   'A snowboarder with brown pants .',
#   'Person wearing grey pants airborne on a snowboard .'],
#  'data\\Images\\197504190_fd1fc3d4b7.jpg': ['Two boys in a field kicking a soccer ball .',
#   'Two children are playing with a soccer ball on grass .',
#   'Two children playing with a ball on the grass .',
#   'Two children play soccer in the park .',
#   'Two little boys are playing outside with their soccer ball on the green grass .'],
#  'data\\Images\\416960865_048fd3f294.jpg': ['A hiker in a red on a snowy peak .',
#   'A person in a red jacket and a red hardhat stands near a mountain .',
#   'A person wearing a red jacket and helmet walks up near the large rock .',
#   "A woman wearing a red work man 's hat and red jacket is hiking in the snow topped mountains .",
#   'The person wearing the red hardhat is on the mountain .'],
#  'data\\Images\\837893113_81854e94e3.jpg': ['A child throwing an orange toy .',
#   'A small child is near a Frisbee .',
#   '"A young boy tries to catch an orange and yellow Frisbee in a green , grassy field ."',
#   'A young boy wearing a large hat reaches to catch a Frisbee .',
#   'A young boy wearing a military sun hat catches a Frisbee outdoors .'],
#  'data\\Images\\3368671163_0171259581.jpg': ['A beige dog runs behind a white dog holding a yellow toy .',
#   'a dog chases another dog with a toy in its mouth .',
#   'a dog running in a park with a rubber chicken in its mouth .',
#   'A white dog carries a yellow toy while another dog follows .',
#   'The dog is holding a yellow toy .'],
#  'data\\Images\\433855742_c2a6fda763.jpg': ["A dog jumps a man 's leg to take a Frisbee from his hand .",
#   'a dog jumps for the Frisbee the girl is holding .',
#   'A person in a black coat playing Frisbee with a dog near a wooded area .',
#   'A woman and a dog play with a disk in a field .',
#   'The dog owner attempts to retrieve the Frisbee from her pet .'],
#  'data\\Images\\2788945468_74a9618cfa.jpg': ['A man is posing in front of a brick wall that has framed pictures on it .',
#   'A man is standing in front of an interior brick wall with pictures along the top .',
#   'a middle aged man is standing next to a white wall underneath some catholic theme pictures .',
#   'A smiling man in a check shirt stands below a row of religious pictures .',
#   'Pictures on a white brick wall with a smiling man standing in front of the wall .'],
#  'data\\Images\\2894217628_f1a4153dca.jpg': ['"A holder and kicker for a football team dressed in orange , white and black play while onlookers behind them watch ."',
#   'A kicker launches the football forward while the holder checks his fingers .',
#   'The football player wearing a white helmet and orange chairs swing his leg while the player next to him kneels .',
#   'Two football player are in the kick off position in front of a crowd .',
#   'Two young men on the same football team are wearing orange and white uniforms and playing on an outside field while coaches and other players watch .'],
#  'data\\Images\\542269487_5d77b363eb.jpg': ['A man and a woman in blue jog on the sidewalk while a man stretches on a park bench .',
#   'An older couple jogging by the water',
#   'Two ladies jogging on a path near the waterfront .',
#   'Two people wearing blue are jogging on a sidewalk in front of a lake with mountains in the backround .',
#   'Two women jogging down a sidewalk in front of a person leaning on a bench in front of a lake . with another person'],
#  'data\\Images\\3520321387_710ab74cda.jpg': ['A lady is smiling with her blonde haired son .',
#   'A woman and a young boy .',
#   'A woman and child laugh .',
#   'A woman and child smile for a picture .',
#   'Mother and son grin for the camera'],
#  'data\\Images\\3336808362_c17837afd8.jpg': ['A man and another person in shadow watch a street parade at night .',
#   'A man sits while in the distance other men are shirtless wearing kilts .',
#   'A man watching something that other people are doing .',
#   'The man is standing on the sidelines looking at people holding blue signs .',
#   'Two people watching the crowd in front of them .'],
#  'data\\Images\\344841963_8b0fa9784c.jpg': ['"A woman wearing black , a woman wearing white and a man wearing a grey suit sit on a green bench in front of Dupar \'s restaurant ."',
#   'Three people are sitting on a bus stop bench in between two tropical palm trees .',
#   'Three people on a bench in front of a restaurant .',
#   'Three people sit on a bench under palm trees .',
#   'Three people sitting on a bus stop bench .'],
#  'data\\Images\\247704641_d883902277.jpg': ['A black dog is slowly crossing a fallen log that is outstretched over a stream of water .',
#   'A dog crossing a river on a bridge made of a fallen tree .',
#   'A dog walks on a log across a small river .',
#   'The black dog is walking along a tree trunk bridge over water .',
#   'The dog walks across the stream on a fallen log .'],
#  'data\\Images\\3235542079_2fcf4951a1.jpg': ['A man in a prison suit is snowboarding .',
#   'A man in a zippered jacket snowboarding .',
#   'A snowboarder in stripes .',
#   'A snowboarder poses for the camera while doing a trick .',
#   'A snowboarder wearing a black and white striped jacket is kicking up some snow .'],
#  'data\\Images\\240583223_e26e17ee96.jpg': ['A brown dog is running on a dirt path .',
#   'A dog is running down a dirt path .',
#   'A running golden retriever',
#   'A yellow dog running down a sandy path .',
#   'The yellow dog is running on the dirt road .'],
#  'data\\Images\\2402793046_3385554e81.jpg': ['A boy climbs a rigging on a boat .',
#   'A boy climbs a sailboat mast .',
#   'A boy wearing climbing gear climbs by a wooden pole .',
#   'A small child climbs ropes hung near a large pole .',
#   'The boy is climbing up a rope ladder .'],
#  'data\\Images\\2074244690_82e30ff44b.jpg': ['A girl who is surrounded by other people is taking a picture at a concert .',
#   'A group of men and women are facing in the direction of something that is happening off camera .',
#   'A group of people gathered at night watching an event .',
#   'A group of people gathered for an event',
#   'Several people are gathered and watching an event .'],
#  'data\\Images\\134894450_dadea45d65.jpg': ['A boy wearing no shirt and some blue jeans is jumping in the air in the woods .',
#   'A guy leaps into the air in a wooded area .',
#   'A shirtless man jumps in a sunny forest .',
#   'a shirtless man jumps over a log .',
#   'The boy is jumping in the woods .'],
#  'data\\Images\\2813588204_69fe7deb14.jpg': ['Two brown dogs race on a track .',
#   'Two dogs are racing and have muzzles on their mouths .',
#   'two dogs race around the course .',
#   'Two dogs wearing racing equipment are running on muddy ground .',
#   'Two racing dogs run in the mud .'],
#  'data\\Images\\772212710_f5fc22ed35.jpg': ['the two girls are carrying several stuffed toy animals .',
#   'Two girls stand on a walkway holding several stuffed animals .',
#   'Two little girls are standing with bunch of stuffed animals on a white stone path .',
#   'Two little girls on a stone path holding stuffed animals .',
#   'Two small girls are holding stuffed animals .'],
#  'data\\Images\\3556598205_86c180769d.jpg': ['A dirt biker aggitates dirt on a four wheeler .',
#   'A man is riding a four wheeler through some dirt .',
#   'A person drives an ATV through mud .',
#   '"A person on an all-terrain vehicle , sending up clouds of dust ."',
#   'A quad sends dirt flying into the air .'],
#  'data\\Images\\3434452829_62cee280bc.jpg': ['A little boy in red walks and eats a snack while a little boy in green walks behind .',
#   'A young boy eats chips while another little boy follows .',
#   'Two children walk on a tiled floor .',
#   'Two little kids walk side by side while one eats something .',
#   'two young children walking on a tiled floor'],
#  'data\\Images\\2709536455_2a6046e38a.jpg': ['Snow dogs howling .',
#   '"These dogs appear to be howling , outdoors in the snow ."',
#   '"Three barking , howling dogs"',
#   'Three dogs standing in the snow with two of the dogs with open mouths .',
#   'two husky dogs are howling together'],
#  'data\\Images\\3215108916_0473007b47.jpg': ['A group of people walking on the side of a railroad track .',
#   'A long view of a curving railroad track with a group of people off in the distance .',
#   'Looking along a railroad track at people in the distance .',
#   '"People are walking away from the camera , along railroad tracks ."',
#   'People near railroad tracks in the woods .'],
#  'data\\Images\\2971478694_79e46ea7e5.jpg': ['A crowd of people in colorful dresses .',
#   'A crowd of women wearing multiple different colors is entering a stone structure .',
#   'Many ethnic people in multi-colored robes gather for an event',
#   'Many women have gathered and are listening to speakers .',
#   'Many women in colorful saris are entering a stone building .'],
#  'data\\Images\\3070130228_67dcfee9ae.jpg': ['Two football players are preparing for the next play .',
#   'Two football players in hike formation .',
#   'Two football players preparing to hike a football .',
#   '"Two people wearing blue , red , and white football uniforms crouched over as though in play ."',
#   'Two players in red white and blue football uniforms squat down on the field .'],
#  'data\\Images\\127450902_533ceeddfc.jpg': ['A winter landscape with four people walking in the snow .',
#   'Beautiful snowy landscape with people treading through the snow .',
#   'Cross-country skiers are traveling towards the mountains at sunset .',
#   'Four people walking across thick snow during a sunset .',
#   'The sun is almost behind the snowy mountains .'],
#  'data\\Images\\2726301121_95a2fbd22b.jpg': ['"A blonde-haired girl wears a tank-top that says "" Thank You "" and sports a large tattoo ."',
#   '"A blond woman with a tattoo of on an angel on her arm walking down the street , a concrete wall in the background ."',
#   'A blond woman with a tattoo on her arm stands near a wall .',
#   'Girl in black t-shirt looks on',
#   'The woman in the tank top has a tattoo on her arm .'],
#  'data\\Images\\1119015538_e8e796281e.jpg': ['A little tan dog with large ears running through the grass .',
#   'A playful dog is running through the grass .',
#   'A small dogs ears stick up as it runs in the grass .',
#   'The small dog is running across the lawn .',
#   'this is a small beige dog running through a grassy field'],
#  'data\\Images\\382701159_f98c1988cd.jpg': ['a man fishes in the ocean .',
#   'A man fly fishes in the ocean .',
#   'A man fly fishing .',
#   'A man is fishing in knee-high waves of water .',
#   '"The person is fishing , with waves splashing around him ."'],
#  'data\\Images\\2139519215_8ca16dd192.jpg': ['A girl walks next to a pool .',
#   'A young girl in a blue and pink bathing suit runs around a pool .',
#   'Girl running next to a pool .',
#   'The girl in a bathing suit runs past the blue pool .',
#   'The girl in the aqua two piece swimsuit is in front of the aqua pool .'],
#  'data\\Images\\3614582606_16bd88dab2.jpg': ['A girl in black hat holding an african american baby .',
#   'A lady with a black hat holds a little girl with a crown of flowers .',
#   'A woman holding a baby after a wedding',
#   'A young woman holds a baby with flowers on its head .',
#   'The red hair woman wearing a black tartan hat holds a baby with flowers on her head .'],
#  'data\\Images\\2164363131_6930455d45.jpg': ['A dog leaps for a toy on a road .',
#   'A man and a dog play with a Frisbee .',
#   'A person holding a Frisbee just out of reach of a white dog on a rural road',
#   'Person holding a Frisbee with a white dog jumping for it on a road .',
#   "The dog jumps up to get the Frisbee in the man 's hand ."],
#  'data\\Images\\944374205_fd3e69bfca.jpg': ['A group of boys play soccer on the grass while another looks down from a rock .',
#   'A group of young boys are playing soccer in front of a small hill',
#   'Children play soccer in a field .',
#   'Eight boys playing soccer in the grass .',
#   'Similarly dressed children are playing soccer in a rocky field in front of a building .'],
#  'data\\Images\\3672106148_56cfb5fc8d.jpg': ['A man is lying in a grassy field reading .',
#   'A man laying in the grass reading .',
#   'A man lays on the grass in a field and reads a book .',
#   'A man lies in the grass reading a book .',
#   'The man is laying in the field reading a book .'],
#  'data\\Images\\2298077331_f9a1488067.jpg': ['A black dog and a brown dog run along a dirt path .',
#   'A black dog runs with a white dog',
#   'Two dogs are running down a dirt path in a grassy field .',
#   'Two dogs run and play together on a narrow dirt path in the middle of a field .',
#   'Two dogs run through the grass outside .'],
#  'data\\Images\\3123770450_cedc16d162.jpg': ['a deer and several turkeys together in the snow',
#   'A deer looks at 5 turkeys in the snow .',
#   'Deer and turkeys in the snow .',
#   'Deer and turkeys stand on snow covered ground .',
#   'Large turkeys and deer stand in the snow .'],
#  'data\\Images\\3139389284_f01bd4c236.jpg': ['A dog leaps down the road .',
#   'A little white dog jumping on the ground .',
#   'A small dog jumping on a street .',
#   'A white dog is jumping on the street .',
#   'The dog is jumping in the air .'],
#  'data\\Images\\2340919359_f56787d307.jpg': ['A man is sitting on a black and brown dog .',
#   'A man stands over a brown and black dog in the grass .',
#   "a man wearing a black and white shirt jumping on a dog 's back",
#   'An attack dog is working with his trainer .',
#   'A running dog and a standing man on a dry field of grass .'],
#  'data\\Images\\3005126574_49c28ffbee.jpg': ['A black man is wearing a brown shirt and a necklace .',
#   'A black man with a necklace is starring off camera .',
#   'A man looks straight ahead at night .',
#   'A man with black skin and short hair wears a necklace and gray shirt .',
#   'An man of African heritage is wearing a grey shirt and silver neck chain .'],
#  'data\\Images\\2628331789_c7f7d90e5d.jpg': ['"A little girl jumps into the arms of her mother , standing in a pool ."',
#   'a woman catches a young boy jumping into the pool .',
#   'A young child is jumping into the arms of a woman wearing a black swimming suit while in a pool .',
#   'The lady catches the toddler in the pool .',
#   '"While others watch , a young girl jumps into a pool as a woman reaches for her ."'],
#  'data\\Images\\3237760601_5334f3f3b5.jpg': ['A person wearing skis makes a jump over the snow .',
#   'A skier',
#   'A skier is in the air .',
#   'A skier takes to great heights on a snow-covered mountain slope .',
#   'The man is skiing down a snowy hill .'],
#  'data\\Images\\2609836649_b55831ed41.jpg': ['A brown and white dog is paddling through deep water in a blue container .',
#   'A brown and white dog swims in a backyard swimming pool .',
#   'A dog is swimming in an above ground pool .',
#   'The brown and white dog swims in a swimming pool .',
#   'The little white and brown dog is swimming in a pool .'],
#  'data\\Images\\2290330500_e7bdaa58e1.jpg': ['a determined girl is hitting a volleyball',
#   'A girl in a grassy field hitting a volleyball .',
#   'A woman plays volleyball .',
#   'A young girl is practicing volleyball in a grass field .',
#   'The girl is hitting the volleyball .'],
#  'data\\Images\\250892549_1e06a06a78.jpg': ['a golden dog with a blue object in its mouth stands next to another golden dog in front of a green fence in a grassy field .',
#   'A heavily scarred pitbull attempts to take a playtoy from another pitbull .',
#   'The two tan dogs greet each other in the green grass .',
#   'Two dogs in a grassy park playing .',
#   'Two tan dogs play with a blue toy in a green field of grass .'],
#  'data\\Images\\3219065971_702c4e8c34.jpg': ['A boy and a person off-camera playing a card game .',
#   'A small boy holding a hand of cards with Uno cards in the foreground .',
#   'Boy sitting on the couch playing a game of Uno .',
#   'The boy is playing UNO .',
#   '"Three UNO cards in reds and yellows in the foreground , with a young boy holding additional cards in the background ."'],
#  'data\\Images\\2484190118_e89363c465.jpg': ['A boy with his hands above his head stands on a cement pillar above the cobblestones .',
#   'A child in colorful shorts is standing on a post in the street .',
#   'A small boy stands on a cement stump in a park with his hands on his head .',
#   'a young man wearing a white t-shirt and green and black shorts standing on a stump .',
#   'Small child in white shirt and print shorts with hands over their head standing on object .'],
#  'data\\Images\\265528702_8653eab9fa.jpg': ['A man in sunglasses and a neatly trimmed beard overlooks a woody valley .',
#   'a man posing with large grassy mountains off in the distance .',
#   'A man wearing sunglasses stands before a forested landscape .',
#   'A man with a beard and sunglasses is standing in front of tree-covered hills .',
#   'Bearded man with sunglasses in the mountains .'],
#  'data\\Images\\3222842866_cb85243ce4.jpg': ['A black and white spotted dog runs along the seaweed and sand .',
#   'A dalmation is running along the beach .',
#   'A Dalmation runs along a beach .',
#   'a dalmation runs along the beach .',
#   'Dalmation running along the beach .'],
#  'data\\Images\\3646453252_5ebbbaa6cc.jpg': ['A child wearing a helmet riding a mountain bike very fast through a forest .',
#   'A cyclist streaks through the trees .',
#   'A person wearing a red helmet riding a white bike .',
#   'A person wearing a red helmet and yellow and white clothing is riding a bike outside in a wooded area .',
#   'The BMX biker rides through the forest .'],
#  'data\\Images\\308014594_f1d5e75507.jpg': ['Two Japanese girls are wearing traditional dress .',
#   'Two Japanese ladies with colorful kimonos on them .',
#   'Two women dressed as geishas .',
#   'Two women dressed in brightly colored traditional asian clothes stand at the top of steps .',
#   'Two women in elaborate Japanese costumes .'],
#  'data\\Images\\2677656448_6b7e7702af.jpg': ['a brown and white dog swimming towards some in the pool',
#   'A dog in a swimming pool swims toward sombody we cannot see .',
#   'A dog swims in a pool near a person .',
#   'Small dog is paddling through the water in a pool .',
#   'The small brown and white dog is in the pool .'],
#  'data\\Images\\414773731_c3f5bf43d5.jpg': ['A black dog is running in snow .',
#   'A brown and black dog running through snow-covered ground .',
#   'A dog is standing in the snow watching the camera',
#   'A dog running on snow and ice .',
#   'A dog with black and brown fur runs in the snow .'],
#  'data\\Images\\2303356248_65dd6aba6f.jpg': ['Kids wearing jackets and hats swinging on tire swing in snow',
#   'Two children swing in a tire in the snow at a park .',
#   'Two children swing on a tire swing on a snowy day .',
#   'Two kids in snow hats and blue and green coats are swinging on a tire swing out in the snow .',
#   'Two young children are being pushed on a tire swing with snow on the ground .'],
#  'data\\Images\\405615014_03be7ef618.jpg': ['A man in a lime green vest directs traffic',
#   'A policeman wearing a green vest blows his whistle and moves his arms .',
#   'A policeman wearing a neon green vest has a whistle in his mouth while directing traffic .',
#   'A police officer in a yellow vest directs traffic .',
#   '"A traffic director wears a yellow safety suit marked , "" Seattle Police . """'],
#  'data\\Images\\2532262109_87429a2cae.jpg': ['A group of 5 girls in school uniforms are standing together and waiting to cross the street while one girl takes a picture .',
#   'A group of people are standing together outside as one takes a photograph .',
#   'A group of school girls are standing together while one is taking pictures .',
#   'A group of young women stand together .',
#   'Girls in school uniforms .'],
#  'data\\Images\\3373544964_c9f1253b7d.jpg': ['"A boy and his dog are standing on a trampoline , enjoying each others company ."',
#   'A boy looks at a dog while they stand on a trampoline outside .',
#   '"A buy with glasses petting his bulldog , on the pavement with woods in the background ."',
#   'A muscular dog with upturned face looking into eyes of a young boy .',
#   'Dog with tongue out looking up at a young boy with glasses'],
#  'data\\Images\\3462512074_2b4db1ffd6.jpg': ['a man on a harness in the middle of climbing through a cave .',
#   'A person hanging off of a cliff on a rope .',
#   'A person rappels off a cliff face .',
#   'A rock climber hangs from a cliff in the mountains .',
#   'A rock climber repels down a cliff face above a heavily wooded area nearby mountains .'],
#  'data\\Images\\2776029171_5abdd5a22f.jpg': ['A little boy is running on the round playing with a little girl .',
#   'a young boy running after a young girl on a beach .',
#   '"Two boys , one naked , one in a skirt , run on the sand ."',
#   'Two kids chasing each other in the sand .',
#   'Two small children running on a beach .'],
#  'data\\Images\\2813784259_d201044d71.jpg': ['A boy wearing a white headband is kicking a soccer ball down the field .',
#   'A player kicks the soccer ball from the corner of the field .',
#   'A soccer game is going on at sundown .',
#   'A soccer player is kicking a soccer ball .',
#   '"At dusk , a soccer player kicks the ball off the sidelines ."'],
#  'data\\Images\\2632111399_b3c1630f8e.jpg': ['"A boy catcher in a helmet , stretching out his gloved hand for a catch ."',
#   'A catcher in a red and white uniform plays at a baseball game .',
#   'A catcher with a red shirt is standing in the dirt with his glove held out .',
#   'A child catcher reaching out his mitt to catch a ball .',
#   'The boy is bending down ready to catch the ball .'],
#  'data\\Images\\2313822078_282dc07531.jpg': ['A child swings on his stomach on a tire swing amidst trees .',
#   'A small child on a tire swing in a forested field .',
#   'a small child playing on a tire swing',
#   'a small kid swinging on a tire swing',
#   'A very little child swings on a tire swing .'],
#  'data\\Images\\130211457_be3f6b335d.jpg': ['A girl in a red and black leotard with white writing is standing next to a man in a cap and a girl in a hot pink and black and white checkered outfit .',
#   'A man has his arms around two women who are posing for a picture with him .',
#   'A man with a backpack and cap posing with two girls dressed in tight uniforms .',
#   'Two blonde models pose with a man under an umbrella .',
#   'Two woman posing with a guy .'],
#  'data\\Images\\1000268201_693b08cb0e.jpg': ['A child in a pink dress is climbing up a set of stairs in an entry way .',
#   'A girl going into a wooden building .',
#   'A little girl climbing into a wooden playhouse .',
#   'A little girl climbing the stairs to her playhouse .',
#   'A little girl in a pink dress going into a wooden cabin .'],
#  'data\\Images\\2290589734_b588471345.jpg': ['One boy in a black shirt is grabbing the flag of the boy in the red shirt with the football .',
#   'Two boys are playing flag football .',
#   'Two boys playing a game of flag football .',
#   'Two boys with mouthguards and one is holding a football while the other reaches for him .',
#   'Young football players with mouthguards .'],
#  'data\\Images\\3240351042_5d29c94b0e.jpg': ['A biker rider jumping high over a dirt hill and seems to be higher than an electric pole .',
#   'A motor biker gets massive air off a dirt jump',
#   'A person jumps a bicycle off a large dirt ramp .',
#   "Brown ramp structure with a person on ski 's in midair .",
#   'The cyclist is airborne on his bike as it makes a jump between two mounds of earth .'],
#  'data\\Images\\3217620013_8b17873273.jpg': ['A basketball player in a red uniform is holding the ball while a player in a white uniform is trying to block him .',
#   'A basketball player with a ball and defenders .',
#   'A man in a red uniform is playing backset ball with a man in a white uniform blocking his shot .',
#   'The rival teams are playing basketball .',
#   'two basketball teams playing a game on the court .'],
#  'data\\Images\\2800004913_c8394ba332.jpg': ['A girl plays in the surf at the beach .',
#   'A kid in an ocean rides a wave .',
#   'A little girl is jumping into a breaking wave on the beach .',
#   'a young man playing in a wave at the beach',
#   'This boy is spreading his arms while playing in the water .'],
#  'data\\Images\\2744705574_519c171ca0.jpg': ['a dog chasing a Frisbee into the water',
#   'A dog holding a Frisbee walking in the water .',
#   'A dog is running through the water with an orange object in its mouth .',
#   'a dog playing in the water',
#   'Dog running on water with a Frisbee in its mouth .'],
#  'data\\Images\\2927878881_90b42fc444.jpg': ['A man holds a stick up for a dog to catch while another dog looks on at the beach .',
#   'A man plays with two dogs on the beach .',
#   'A man standing on a beach is playing with two dogs .',
#   'Someone playing with their dogs on the beach .',
#   'Two dogs play with a man on the beach .'],
#  'data\\Images\\2021671653_567395c7cf.jpg': ['A boy dressed in denim is running on the sidewalk .',
#   'A young boy in motion in front of potted plants and a beige wall .',
#   'a young boy wearing a denim outfit running down the street',
#   '"Little boy in denim runs through paved , Spanish-style yard area ."',
#   '"Young boy running waring blue jacket and blue jeans , flower pots are in the background on a cement walkway ."'],
#  'data\\Images\\1019604187_d087bf9a5f.jpg': ['A dog prepares to catch a thrown object in a field with nearby cars .',
#   'A white dog is about to catch a yellow ball in its mouth .',
#   'A white dog is about to catch a yellow dog toy .',
#   'A white dog is ready to catch a yellow ball flying through the air .',
#   'A white dog running after a yellow ball'],
#  'data\\Images\\516214924_c2a4364cb3.jpg': ['A brown dog chews on an orange ball .',
#   'A dog bites a big orange ball .',
#   'A dog has an orange ball in its mouth .',
#   'A dog playing with a ball .',
#   'The brown dog has an orange ball in its mouth .'],
#  'data\\Images\\3569979711_6507841268.jpg': ['A boy does a flip on the beach .',
#   'A boy doing a flip in the air at the beach .',
#   'A man doing a back flip on the beach .',
#   'A person in midair doing a flip along the beach',
#   'A teenage boy is doing a back flip in midair on the beach .'],
#  'data\\Images\\2396669903_5217a83641.jpg': ['"A man carries two grocery bags , a sign of a funny man is by the pole near him ."',
#   'A man dressed in a brown coat and bomber hat is carrying shopping bags and walking towards an intersection .',
#   'A man is carrying bags nearby an elevated roadway and crosswalk .',
#   'A person in a cap with earflaps carries two grocery bags down a city street past a poster of a mustached man .',
#   "Sombody has stuck the face of Groucho Marx on a walk do n't walk button ."],
#  'data\\Images\\3533775651_9d7e93dacf.jpg': ["A person in red is opening a red car 's door in a parking area .",
#   'a woman gets out of a red car .',
#   'Two people embrace outside of a red car at night in a brightly-lit city .',
#   'Two people standing next to a red car are hugging in traffic with a brightly lit city scene behind them .',
#   'Two people stand outside of a red car in the city and hug .'],
#  'data\\Images\\1015118661_980735411b.jpg': ['A boy smiles in front of a stony wall in a city .',
#   'A little boy is standing on the street while a man in overalls is working on a stone wall .',
#   'A young boy runs aross the street .',
#   'A young child is walking on a stone paved street with a metal pole and a man behind him .',
#   'Smiling boy in white shirt and blue jeans in front of rock wall with man in overalls behind him .'],
#  'data\\Images\\3338217927_3c5cf3f7c6.jpg': ['A black dog in snow is jumping off the ground to catch a stick .',
#   'A dog jumping for a Frisbee in the snow .',
#   'A dog jumps to catch a toy in the snow .',
#   'A dog plays in the snow .',
#   'Black dog jumping into the air to catch a toy in the snow .'],
#  'data\\Images\\291952021_f111b0fb3d.jpg': ['A brown and white dog carries a brown and white dish towel in his mouth .',
#   'A brown and white dog with big brown eyes with a dishtowel in his mouth on a hardwood floor .',
#   'A dog looking at the camera with a piece of cloth in its mouth .',
#   'Pink eyed boxer dog carrying a pillowcase .',
#   'PitBull holding a plaid dish towel in its mouth .'],
#  'data\\Images\\3659769138_d907fd9647.jpg': ['A plane flies with a cloud of smoke behind it .',
#   'A plane is diving through the sky creating a cloud of smoke behind it .',
#   'a small airplane flying through the air with lots of smoke coming out of the plane .',
#   '"A stunt plane is billowing smoke into a clear , grey sky ."',
#   'The airplane is billowing smoke and looks like it may crash .'],
#  'data\\Images\\2114739371_83aa8bdb0e.jpg': ['A brown and black dog leaps through the freshly mown grass .',
#   'a dog runs through the grass .',
#   'A shepherd bounds through the grass .',
#   'Black and brown dog running on grass .',
#   '"Brown and tan dog , mouth open with tongue hanging out , running in the grass ."'],
#  'data\\Images\\3187096035_65dc416291.jpg': ['A group of friends are laughing and playing the wii on a red couch .',
#   'A group of laughing people on a red couch .',
#   'Four happy people sitting on a red couch',
#   'Four people laughing and sitting on a couch .',
#   'People sitting on a couch laugh .'],
#  'data\\Images\\3527926597_45af299eee.jpg': ['A boy on a skateboard is riding on a slope .',
#   'A boy on a skateboard ramp .',
#   'A boy skateboards on a ramp .',
#   'a boy wearing a red shirt rides a skateboard up a ramp',
#   'A young boy skateboarding'],
#  'data\\Images\\3523559027_a65619a34b.jpg': ['"A formation on a big field with people wearing red , white and blue"',
#   'Many people in formation on a field .',
#   'Marching bands in formation on a field .',
#   'The crowd stood in many different lines in the open field .',
#   'The group of people make single file lines on the field .'],
#  'data\\Images\\3613667665_1881c689ea.jpg': ['A black dog runs across the water at a beach while another follows .',
#   'A pair of black dogs runs in the surf .',
#   'Dogs run in the surf .',
#   'The black dog is running through the water on the beach .',
#   'Two black dogs splash through the waves on a beach .'],
#  'data\\Images\\3062273350_fd66106f21.jpg': ['men wearing hats and coats are walking together',
#   'a group of old men walking down the street',
#   'A group of seven men walking and standing on a concrete surface .',
#   'A group of walking men .',
#   'Seven older gentlemen walking together in a group outside .'],
#  'data\\Images\\3033825101_44a4390f16.jpg': ['A baseball pitcher is bowling the ball .',
#   '"A man playing baseball , throwing the ball ."',
#   'A pitcher throws the ball .',
#   'Minor league pitcher',
#   '"The guy is in a baseball uniform , in a baseball field , and is throwing a baseball"'],
#  'data\\Images\\1356796100_b265479721.jpg': ['A girl in a flowered dress peaking through some leaves .',
#   'A girl peeks through the leaves on a tree .',
#   'a girl peeks through the green leaves .',
#   'A young girl peers through the green foliage .',
#   "A young girl 's face looking through leaves ."],
#  'data\\Images\\1130401779_8c30182e3e.jpg': ['Two brown dogs are creating large splashes as they run in a river .',
#   'Two brown dogs in the water .',
#   'Two brown dogs running through water .',
#   'Two brown dogs runs through the water .',
#   'Two dogs splash through the water .'],
#  'data\\Images\\2561849813_ff9caa52ac.jpg': ['"A baby sits on an empty beach under a big , blue sky ."',
#   'A toddler sits on a sandy beach .',
#   'Baby sitting at a beach .',
#   'The baby sits on the sand in the front of the scene while the ocean is in the distance .',
#   'The baby sits on the sandy beach .'],
#  'data\\Images\\2755362721_368cbde668.jpg': ['A greyhound racing .',
#   'A muzzled greyhound dog wearing yellow and black is running on the track .',
#   "A race dog 's feet dig in the mud as he makes his way around a curve .",
#   'Sand is kicked up as two animals run .',
#   '"Two dogs on a wet , sandy track ."'],
#  'data\\Images\\214543992_ce6c0d9f9b.jpg': ['A black and white dog is playing with a ball on a lawn .',
#   'A black and white dog jumps up as a ball is thrown over his head .',
#   'dog jumping looking up and small white ball in air passed by',
#   'The black and white dog is attempting to catch a ball in the garden .',
#   'The dog jumps up waiting to catch something being thrown .'],
#  'data\\Images\\3299820401_c2589186c5.jpg': ['A dirt biker rides through some trees .',
#   'A man is riding a mountain bike through woodland .',
#   'A mountain biker is racing through a shaded trail .',
#   'A mountain biker wearing a colorful helmet rides downhill .',
#   'Mountain biker in red striped helmet rides through the trees .'],
#  'data\\Images\\2267923837_ae88678497.jpg': ['A group of four kids stand in front of a statue of a large animal .',
#   'Children smiling and waving at camera',
#   'Four children .',
#   'Four children are standing to pose for a photo .',
#   'Four dirty and barefooted children .'],
#  'data\\Images\\3525453732_f74a38f111.jpg': ['A bird flies low with its wings spread .',
#   'An owl has its wings up and widespread during the day .',
#   'An owl is in flight .',
#   'A pale owl is flying outside in the daytime .',
#   'The bird has its wings spread as it flies .'],
#  'data\\Images\\2249480913_e1695e5c28.jpg': ['A brown dog and a spotted dog squabble over a dog toy .',
#   'Two dogs are fighting over a red Frisbee outside .',
#   'Two dogs are fighting over a red Frisbee that is bent in half .',
#   'Two dogs play with a Frisbee .',
#   'Two younger dogs biting a Frisbee playfully .'],
#  'data\\Images\\159712188_d530dd478c.jpg': ['A woman is walking past an artificial waterfall .',
#   'A woman is walking with someone else beside a pond in the city .',
#   'A woman talking on a cellphone walking in front of water .',
#   'A woman walks by a river across city buildings .',
#   'Young woman in a city park near a water feature .'],
#  'data\\Images\\2280525192_81911f2b00.jpg': ['a brown and black dog jumping through a field of long blades of grass',
#   'A dog runs through the tall grass .',
#   'A dog wearing a red harness runs across a field',
#   'Black and brown dog with red harness in high grass .',
#   'Dog running through the weeds .'],
#  'data\\Images\\2325386353_1f1a05e1ce.jpg': ['a boy in a mask holds up two bags of bread .',
#   'a boy wears a wrestling mask and carries bags of bread .',
#   'A boy with a blue wrestler mask is posign next to several other people .',
#   'A man child carries two loaves of bread through the store .',
#   'A young boy wearing a mask stands holding two bags of bread .'],
#  'data\\Images\\895502702_5170ada2ee.jpg': ['A black and white dog is chasing a ball on an open plane .',
#   'A black and white dog is running through a grassy area .',
#   '"A black and white dog runs on a dry , yellow field of grass ."',
#   'A dog is running towards a ball .',
#   'A dog runs through a field chasing a ball .'],
#  'data\\Images\\3257207516_9d2bc0ea04.jpg': ['A boy and a woman in Arab costume making peace signs .',
#   'A boy and a young woman in a headscarf make peace signs .',
#   'A girl in a headdress and a boy with a bandanna are giving the peace sign to the camera .',
#   'A woman wearing a blue headcover and a boy wearing a scarf hold fingers in peace signs .',
#   'A woman with a blue headdress and a boy with a headband make a peace sign with their fingers'],
#  'data\\Images\\3516312179_f520469038.jpg': ['a baseball player in a red shirt and white pants is swinging the bat towards a yellow ball whilst three people look on .',
#   'A baseball player recoils from an action involving a bat while opposing team members look on .',
#   'A girl in a red and white uniform is swinging a bat .',
#   'A girl swings a bat during a softball game .',
#   'A woman swings at a softball on a playing field while other players look on .'],
#  'data\\Images\\2892989340_bb7e0e5548.jpg': ['A boy on a surfboard in midair .',
#   'A surfer hangs in the air over the water .',
#   'A young man jumps with a surfboard over the waves .',
#   'Young man surfing in the ocean .',
#   'Youth in white T-shirt on a white surfboard in the water .'],
#  'data\\Images\\2528547068_7d37479b9b.jpg': ['A race car drives through a dirt-covered racetrack .',
#   'A red car emitting smoke while on a paved track .',
#   'A red race car pulls off the track smoking .',
#   'A red race car travels down a road marked with red and white striped ribbons .',
#   'A red rally car taking a slippery turn in a race .'],
#  'data\\Images\\2542662402_d781dd7f7c.jpg': ['A woman in a blue shirt guides her dog over an obstacle .',
#   'a woman is running beside a dog that is jumping over a red and white obedience training fence .',
#   'A woman next to a dog which is running an obstacle course .',
#   'A woman walking with a Sheltie through a competition obstacle course .',
#   'The dog is jumping over the hurdles beside a woman .'],
#  'data\\Images\\2277081067_d2b4c98bce.jpg': ['A boy and girl are splashing around in the ocean .',
#   'Two girls are at the beach playing in the ocean .',
#   'Two girls playing at the beach one in pink and the other in black .',
#   'Two girls walking in the ocean .',
#   'Two young girls are wading in the ocean wearing shorts and sweat shorts .'],
#  'data\\Images\\2693539377_5442430f81.jpg': ['a boy and girl riding a roller coaster',
#   'Children on a ride at an amusement park .',
#   'The children are smiling whist sitting on a fairground ride .',
#   'Two children swing around on a carnival ride .',
#   'two little kids having fun at a roller coaster'],
#  'data\\Images\\938162709_21443d352f.jpg': ['A cross-country skier following a path .',
#   'A cross-country skier going through the woods .',
#   'A person is cross-country skiing through the snow .',
#   'A skier is by himself in the woods .',
#   'Lone skier walks through the snow .'],
#  'data\\Images\\2061397486_53a61e17c5.jpg': ['A black dog with brown markings wearing a red vest trots down a path .',
#   'A brown and black dog is running along a grassy path wearing a red jacket .',
#   'A dog with a reflective garmet running down a rural road',
#   'Brown and black dog with red and white jacket run on road in rural area .',
#   'Dog with a red cape running on a dirt road .'],
#  'data\\Images\\3453284877_8866189055.jpg': ['A guy is grinding a rail over a tree on his snowboard .',
#   'A man snowboarding making a jump off a steel guardrail .',
#   'A snowboarder grinding up a homemade ramp .',
#   'a snowboarder is riding his board on ramp made from a piece of metal and a log .',
#   'The man is skateboarding over a log in the snow .'],
#  'data\\Images\\407678652_1f475acd65.jpg': ['A group of hikers climb rocky terrain .',
#   'Five backpackers hiking along a rocky slope .',
#   'five hikers walk down the hillside .',
#   'Five people with backpacks hiking down a rocky hill .',
#   'The hikers descend on the mountain .'],
#  'data\\Images\\315880837_90db309bab.jpg': ['Three dogs are playing in the white snow .',
#   '"Three dogs , one holding a red Frisbee , standing in snow ."',
#   'Three dogs playing with a Frisbee in the snow .',
#   'Three dogs playing with a toy in the snow .',
#   'Three dogs play with a Frisbee in a snowy field .'],
#  'data\\Images\\2510029990_7014f907cb.jpg': ['A boy slides down a slide with his legs apart .',
#   'A little boy sliding down a slide while laughing .',
#   'A smiling boy with a blue sweatshirt and camouflage shorts on a metal slide in the grass .',
#   'Child in a blue hoodie and shorts is sliding down a slide .',
#   'The boy is sliding down a metal slide .'],
#  'data\\Images\\848180689_d67a1361ce.jpg': ['A girl and a woman playing with a ball in a pool .',
#   'a woman and a little girl are playing with a ball in the pool underneath some water chutes .',
#   'a young girl and a woman play volleyball with a beach ball .',
#   'The mother and daughter are batting a ball in the air to each other at the water park .',
#   '"Two girls in a pool , one catching a ball the other has thrown ."'],
#  'data\\Images\\3279524184_d5e2ffbaed.jpg': ['Two black and white dogs and one has something blue in its mouth .',
#   'Two black and white dogs run through a field .',
#   'Two white dogs are running through a field .',
#   'Two white dogs run along a light colored field and one has a blue toy .',
#   'Two white dogs with black spots jumping through the grass .'],
#  'data\\Images\\123889082_d3751e0350.jpg': ['A brown dog biting a gray dogs ear .',
#   'Brown dog biting a grey dogs ear .',
#   '"Tan dog on grass with mouth open , about to bite gray dog \'s ear ."',
#   'Two dogs are playing in a grassy field ; one dog is biting the ear of the other dog .',
#   'Two dogs are playing together on green grass .'],
#  'data\\Images\\3461106572_920c8c0112.jpg': ['A group of 5 people standing wearing name badges',
#   'A group of people posing in a concert area .',
#   'five people are standing in front of an industrial style building posing for a photograph .',
#   'Five people pose for a picture in a gym .',
#   'Five people wear name tags on a necklace and pose together .'],
#  'data\\Images\\3025495499_b15797b452.jpg': ['a tennis player hits the ball .',
#   'A tennis player hits the ball and makes a serious face .',
#   'A woman in a green sport outfit is attempting to hit a tennis ball with a racket .',
# ...
#   'Two children reaching out toward a swimming seal .',
#   'Two children touch the glass of a large tank containing a seal .',
#   'Two young boys touching glass where they can see a seal swimming by .'],
#  'data\\Images\\2607383384_d9ce9de793.jpg': ['Four women wearing energizer bunny ears point to an attraction .',
#   '"Several women , wearing pink "" Energizer "" bunny ears , point to the right ."',
#   'There are 4 women wearing pink Energizer bunny ears .',
#   'The women have pink bunny ears on their heads .',
#   'Women wearing bunny ears and race numbers point at something in the distance .'],
#  'data\\Images\\3033686219_452b172ab0.jpg': ['A black dog lays in the sand .',
#   'A black dog sits in sand .',
#   'A black dog with a red collar sitting in the sand .',
#   'a black lab sits in the sand .',
#   'A brown dog sits on the beach .'],
#  'data\\Images\\399246804_b4b5dc70e1.jpg': ['A black dachshund sniffs another dog wearing a striped shirt .',
#   'A dog wearing a striped sweater touches noses with another dog .',
#   'A white dog wearing a zepra print shirt is nose to nose with a black dog wearing a pink collar .',
#   'A white dog with a sweater on and a black and brown dog touching noses .',
#   'Two dogs meeting nose to nose .'],
#  'data\\Images\\2911552402_5166bc173b.jpg': ['A biker does a trick on a ramp .',
#   'A biker on top of a shallow hill attempts a trick nearby a gate and grassy area .',
#   '"A man stands on the front wheel of his bicycle , doing a trick ."',
#   'A person does tricks on their bike .',
#   'Man is performing a trick with a bicycle on a ramp .'],
#  'data\\Images\\3399312265_9c74378692.jpg': ['A black dog fighting with a brown dog in the snow .',
#   '"Brown and black dogs on snow , showing teeth and barking at each other ."',
#   'Two dogs are fighting in the snow .',
#   'Two dogs fighting in the snow .',
#   'Two dogs fight in the snow .'],
#  'data\\Images\\3014015906_fdba461f36.jpg': ['Three boys in orange shorts are walking on the rocks beside a woodland stream .',
#   'Three boys in swimming trunks walk upstream .',
#   'Three men only in shorts walking along a river',
#   'Three people walking along a stream in a jungle .',
#   'Three people wearing shorts walk on rocks along the side of a stream in the woods .'],
#  'data\\Images\\3171347658_f0d5469c56.jpg': ['A driver with a white helmet is sitting in a yellow race car .',
#   'a man sitting inside some sort of yellow vehicle',
#   'a person in a white helmet strapped into a yellow car',
#   'A person with helmet is sitting inside a yellow vehicle .',
#   "Bird 's eye view of a driver in his car"],
#  'data\\Images\\2602306033_2b3100d36b.jpg': ['A black dog biting onto something is swimming in the beach .',
#   'A black dog with a stick swimming in the ocean .',
#   '"A dog with a Frisbee , swimming in a lake ."',
#   'Big black dog swimming in the ocean with something in his mouth .',
#   'Dog swimming in the water with a stick .'],
#  'data\\Images\\3259991972_fce3ab18b2.jpg': ['A break dancer spins on his head outside as onlookers watch the performance .',
#   'A man spinning on his head on a city sidewalk near a checkerboard mat .',
#   'A man stands on his head in front of a crowd .',
#   'Man standing on his head near a black and white pattern in the street .',
#   'Young man break dancing in the street .'],
#  'data\\Images\\2394763838_99d1435b85.jpg': ['A blond dog runs in the grass holding a stick in its mouth .',
#   'A golden colored dog jumps around in the grass while holding a stick in its mouth .',
#   'A pale tan dog is carrying a stick in its mouth outside .',
#   'a small tan dog running in the grass with a stick in his mouth',
#   'A tan dog carrying a stick runs over a garden hose lying in a low cut grassy area .'],
#  'data\\Images\\3090386315_87ed417814.jpg': ['a dog runs across the leaf covered ground .',
#   'A dog with a collar and tag runs with its tongue out on a path .',
#   'A tan dog runs in the fall leaves .',
#   'A yellow lab trotting through grass and fallen leaves .',
#   'The tan dog runs through the leaves .'],
#  'data\\Images\\3428386573_670f5362f0.jpg': ['A male tennis player standing on a tennis court swings his tennis racket at the tennis ball .',
#   'A man plays tennis .',
#   'A man wearing white turns to hit a yellow tennis ball .',
#   '"A tennis player focuses on the ball as he prepares to hit it , while a cameraman stands in the background next to a La Quinta advertising logo ."',
#   'The tennis player holds his racket up anticipating the ball .'],
#  'data\\Images\\2195620255_6693479734.jpg': ['Two brown dogs trot along frozen ground in a rural setting .',
#   'Two dogs play out in the snow covered grass .',
#   'Two dogs run through a snow-patched desert .',
#   'Two golden retrievers running in a slightly snowy desert .',
#   'Two golden retrievers running in a snow dusted field .'],
#  'data\\Images\\3077166963_fe172c709d.jpg': ['A girl is standing on logs and taking a picture .',
#   'A girl stands on two logs as she photographs the field .',
#   'A girl stands on two thin logs and photographs buffalo across a river .',
#   'A young woman stands on a tree branch over a river taking a picture of buffalo .',
#   'Woman stands on fallen trees near winding river taking photographs of animals .'],
#  'data\\Images\\576920249_df1bdc2068.jpg': ['A child in a white shirt clapping their hands .',
#   'A girl raises her hands up in a crowd of people .',
#   'A little boy wearing a white shirt and gray pants appears to be dancing .',
#   'A young boy dances in a crowd .',
#   'Crowd of people outside with child in center with hands raised .'],
#  'data\\Images\\3472485022_5d03e9852d.jpg': ['A brown and white pitbull runs through the grass with a stick in its mouth .',
#   'A brown dog carries a long stick on the green grass .',
#   'A brown dog running with a long stick in his mouth .',
#   'The brown dog carried the stick in the grass .',
#   'The large brown dog is running through the grass with a large stick in its mouth .'],
#  'data\\Images\\3537474810_cf676b3259.jpg': ['a man in a blue uniform kicking the soccer ball down the field',
#   'A man in a sports uniform kicking a soccer ball while other players follow him',
#   'A soccer player in blue is striking the ball whilst being pursued by a player in green .',
#   'A soccer player in blue uniform attempts to make a play with a player in green closing in .',
#   'Man in blue shirt kicks soccer ball .'],
#  'data\\Images\\766346887_a9a9d0637a.jpg': ['A boy and a girl go down a metal slide .',
#   'A boy and girl going down a metal slide .',
#   'A little girl and a little boy hold hands on a shiny slide .',
#   'Two children playing on a metal slide .',
#   'two children slide down a slide .'],
#  'data\\Images\\1164765687_7aca07bbe7.jpg': ['A man in a red shirt and glasses is bending down towards a small dog on a blanket with several stuffed animals .',
#   'A man in a red shirt is giving toys to a small dog .',
#   'A man is playing tug of war with his dog .',
#   'A man playing with a black dog on a white blanket .',
#   'A man playing with his dog on the blanket on the floor .'],
#  'data\\Images\\207275121_ee4dfa0bf2.jpg': ['A brown dog running in a yard .',
#   '"A dog runs on the grass in a yard , a gazebo in the background ."',
#   "A dog trotting through someone 's yard .",
#   'A large brown dog is running through a grassy backyard .',
#   'Large brown dog runs through a large grassy area .'],
#  'data\\Images\\2245916742_73af13c733.jpg': ['a man in green holding a camera stands between two of the head statues on Easter island .',
#   'A man stands between to large sculptures on a field .',
#   'A man stands by two face structures on Easter Island .',
#   'A person stands between two giant statues that look like faces .',
#   'A person stands next to the Easter Island statues .'],
#  'data\\Images\\2925242998_9e0db9b4a2.jpg': ['a female hiker is looking at the view of some mountains .',
#   'A lady is standing on the edge of a hill looking at the Verizon .',
#   'A woman hiker stopped at the top of a mountain with a beautiful view',
#   '"A woman in hiking gear on the top of a mountain , looking down at the valley below ."',
#   'A woman stands on a mountain looking at others .'],
#  'data\\Images\\823697339_aadbeef495.jpg': ['a redheaded woman eating some food with a few people standing around her',
#   'A woman wearing black is standing by a woman with bright red hair outside a storefront .',
#   '"People , one of which is a redhead , are standing near the entrance to a store ."',
#   'Two girls stand outside of a shop .',
#   '"Two women , one with red hair , stand outside a store ."'],
#  'data\\Images\\3511890331_6163612bb9.jpg': ['A jockey in blue gallops a chestnut horse on a dirt track past a wooden fence .',
#   'A jockey in blue rides a horse at a galloping pace .',
#   'A jockey racing a horse down a dirt track .',
#   'A jockey wearing a blue jacket is riding a dark brown horse in a gallop .',
#   'A man wearing blue rides a brown horse along a gravel path .'],
#  'data\\Images\\3259666643_ae49524c81.jpg': ['A basketball player performing a lay-up .',
#   '"A boy in a blue basketball uniform , number 13 and a boy in a white basketball uniform , number 23 jump for the ball ."',
#   'A man in a white uniform jumps while holding a basketball as another in blue blocks him .',
#   '"Basketball player wearing a white , number 23 jersey jumps up with the ball while guarded by number 13 on the opposite team ."',
#   'The man in white is playing basketball against the man in blue .'],
#  'data\\Images\\58363930_0544844edd.jpg': ['A hiker treks up the snowy mountain .',
#   'A man climbing a snowy mountain .',
#   'A man skiing in the mountains',
#   'A mountaineer is ascending a snow covered trail whilst attached to a rope .',
#   'A person in a blue hat climbing up a snow covered mountain .'],
#  'data\\Images\\2273105617_7c73d2d2d3.jpg': ['a elderly woman in a tan jacket is standing by the door of a wooden house carrying a green and beige bag .',
#   'A man in a brown coat standing on a porch',
#   'A man in a brown jacket standing in front of an open porch door .',
#   'An old lady standing on a porch looking off in the distance',
#   'The lady on the porch is wearing a brown jacket .'],
#  'data\\Images\\2643263887_a32ffb878f.jpg': ['A boy going down a water slide .',
#   'A boy in green trunks slides down a water slide .',
#   'A boy slides down an inflatable water slide .',
#   'A child reaches the bottom of an inflatable slide .',
#   'A young boy smiling as he rides down an inflatable water slide .'],
#  'data\\Images\\1225443522_1633e7121f.jpg': ['A girl walking alone at night on a street .',
#   'A woman in a blue coat and blue heels walks down a city sidewalk at night .',
#   'A woman walking down a brick sidewalk .',
#   'A woman walks down a brick sidewalk at night .',
#   'A woman walks down a city sidewalk at night .'],
#  'data\\Images\\3522349685_f046f0e250.jpg': ['A child petting a dog .',
#   '"A little girl is petting her white , fluffy cat ."',
#   'A smiling girl in orange hold a furry animal .',
#   'small girl petting an animal .',
#   'Young girl in ponytail pets furry cat'],
#  'data\\Images\\2894576909_99c85fd7a7.jpg': ['A kayaker crashes against the force of the wave .',
#   'a lone person in a red boat on a wild river with only one padel',
#   'A man pilots a kayak through rough rapids .',
#   'A person riverrafting .',
#   'This person in a red kayak faces a challange in the rapids .'],
#  'data\\Images\\801607443_f15956d1ce.jpg': ['One climber is sitting on the rock overlooking the ocean whilst another climber is on her way up .',
#   'Two people are on a rock overlooking the ocean',
#   'Two people climb a rock overhanging water .',
#   'Two people climb rocks over some water .',
#   'Two people rock climbing near water .'],
#  'data\\Images\\260828892_7925d27865.jpg': ['a lone person walking in the distance on a long beach .',
#   'A man is walking on the beach and leaving some footprints behind',
#   'A person walks along the beach and leaves footprints in the sand .',
#   'A woman in a black dress is leaving footprints in the sand as she walks towards the ocean .',
#   'woman walking on sand leaving footprints'],
#  'data\\Images\\1445123245_c7b9db0e0c.jpg': ['A black and tan dog plays with a centipede toy .',
#   '"A dog tags a nap on a rug near his favorite toy , a plush centipede ."',
#   'A short long haired dog plays with a multi-colored stuffed toy centipede .',
#   'A small brown and black dog plays with a colorful caterpillar toy on a tan burbur carpet .',
#   'Yorkshire Terrier plays with multicolor centipede toy .'],
#  'data\\Images\\2089426086_7acc98a3a8.jpg': ['A girl in a hooded jacket presents a cake with candles .',
#   'A girl in a hood jacket holds a birthday cake with many candles .',
#   'A girl in a winter coat with a birthday cake .',
#   'A girl is holding a birthday cake .',
#   'A young girl holding a cake with candles dressed in a heavy coat .'],
#  'data\\Images\\3562302012_0cbcd01ff9.jpg': ['A boy crawls under a house outside .',
#   'A boy in blue jeans stands in the scoop of a bulldozer .',
#   'a boy stands on a black bench .',
#   'A boy wearing a black shirt is climbing inside the bucket of a mechanical digger .',
#   'Little boy wearing jeans is playing on industrial equipment .'],
#  'data\\Images\\3373243733_9aba7740ed.jpg': ['A person in a black jacket doing tricks on a motorbike .',
#   'A person on a bike doing a wheelie on a rock .',
#   'A person on a motorcycle doing a wheelie off of a rock .',
#   'A person rides their bicycle onto a rock and balances on one wheel .',
#   'The man is riding a motorcycle over jagged rocks .'],
#  'data\\Images\\1248953128_24c9f8d924.jpg': ['A little girl in a colorful dress is playing with a blue and red soccer ball .',
#   'A little girl in a dress playing with a soccer ball .',
#   'Girls in brightly-colred clothes plays with a blue ball .',
#   'The young girl is kicking a blue and red soccer ball .',
#   'Young girl in blue dress stepping over a soccer ball .'],
#  'data\\Images\\2460159430_71ab1aacfa.jpg': ['A brown dog races through a field .',
#   'a brown dog running through the tall grass .',
#   '"A dog running in long grass , a housing development behind it ."',
#   'A tan dog is bounding through grass .',
#   'Two dogs running through tall grass .'],
#  'data\\Images\\2064790732_219e52e19c.jpg': ['A boy without a shirt is running in the street while several people stand behind him .',
#   'A little boy dances with a group of people behind him on a city street .',
#   'A small boy dances on the concrete surrounded by adults .',
#   'The little boy wearing no shirt is running by a crowd of people .',
#   'The shirtless little boy is walking around adults .'],
#  'data\\Images\\3533660418_f3a73a257c.jpg': ['"These three men , two with turbans , are sitting on the edge of a cement bench ."',
#   'Three Arabian men sitting under an awning .',
#   'Three men holding their faces on a sidewalk .',
#   'Three men sit on a bench outside .',
#   'Three Middle Eastern men are sitting on a sidewalk together .'],
#  'data\\Images\\3411022255_210eefc375.jpg': ['A group of people are in front of a store walking across a crosswalk .',
#   'A group of people walking across a street',
#   'Four people and a baby are crossing the street at a crosswalk .',
#   'Four people and a child walking in the street .',
#   'People crossing the street'],
#  'data\\Images\\3296150666_aae2f64348.jpg': ['A large vehicle drives through a mud puddle .',
#   'A large vehicle travels through a bumpy and muddy path .',
#   'An off road vehicle driving through a mud puddle .',
#   'An SUV traveling through mud .',
#   'A sport utility vehicle is driving through deep and muddy water .'],
#  'data\\Images\\241346105_c1c860db0d.jpg': ['A college football game is in progress .',
#   'A football player runs along the sidelines with a football as a crowd watches .',
#   'An American footballer in a red strip is running down the side of the field with the ball .',
#   'The football player is running with a football trying to score .',
#   'The football player is trying to outrun his opponent .'],
#  ...}
